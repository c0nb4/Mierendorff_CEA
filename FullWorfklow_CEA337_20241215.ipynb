# %%
# Import packages
import datetime
import geopandas as gpd
import holidays
# import july
import numpy as np
import os
import re 

import pandas as pd
from matplotlib import pyplot as plt
from dbfread import DBF
# import seaborn as sns
import shutil
import time
# Import CEA modules
import cea.config
import cea.api 
from cea.utilities.dbf import *
from cea.utilities.epwreader import epw_reader
from cea.datamanagement.archetypes_mapper import archetypes_mapper
from cea.datamanagement.archetypes_mapper import main as archetypes_mapper_main
from cea.demand.schedule_maker.schedule_maker import main as schedule_maker
from cea.demand.demand_main import main as demand_main
from cea.resources.radiation.main import main as radiation_main

#Take default dependencies for DAYSIM
# DAYSIM_BIN_DIRECTORY = os.path.join(os.getcwd(), 'CEA_model', '0_daysim_binaries')
project_folder = os.path.join(os.getcwd(), 'CEA_model337_12')


zone_gdf = gpd.read_file(
    os.path.join(project_folder, 'Baseline', '2020', 'inputs', 'building-geometry', 'zone.shp')) 
list_buildings = zone_gdf["Name"].tolist() 

selection_gdf = zone_gdf.copy()

selection_gdf.head()
# Out:
#     Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0  B1000        2.0          2        3.0          1        NaN      school
# 1  B1001        3.0          3        3.0          1        NaN     service
# 2  B1002        1.0          1        3.0          1        NaN         yes
# 3  B1003        1.0          1        3.0          1        NaN         yes
# 4  B1004        6.0          6        3.0          1        NaN  apartments
#
#         REFERENCE house_no               street postcode  house_name  \
# 0  OSM - as it is      NaN                  NaN      NaN         NaN
# 1  OSM - as it is       10  Lise-Meitner-Straße    10589         NaN
# 2  OSM - as it is      NaN                  NaN      NaN         NaN
# 3  OSM - as it is      NaN                  NaN      NaN         NaN
# 4  OSM - as it is      NaN                  NaN      NaN         NaN
#
#    resi_type    city country  \
# 0        NaN     NaN     NaN
# 1        NaN  Berlin      DE
# 2        NaN     NaN     NaN
# 3        NaN     NaN     NaN
# 4        NaN     NaN     NaN
#
#                                             geometry
# 0  POLYGON ((384874.043 5820594.084, 384873.807 5...
# 1  POLYGON ((385147.715 5821181.978, 385145.006 5...
# 2  POLYGON ((385315.603 5820595.263, 385265.770 5...
# 3  POLYGON ((385231.453 5820685.213, 385230.993 5...
# 4  POLYGON ((385092.809 5820650.440, 385096.097 5...

# %%
selection_gdf.plot()
# Out:
# <Axes: >

# %%
# drop everything that is smaller than 40m2  
selection_gdf["area"] = selection_gdf["geometry"].area
buildings_above_40sqm = selection_gdf.query('area> 40')["Name"]

# %%
# adjust type on main type for block 
# first check if there is an overlap 
dir_path = os.getcwd()
shape_data_path = os.path.join(dir_path, 'auxillary',  '00_block_shape.shp')
shapes = gpd.read_file(shape_data_path)
shapes["blknr"] = shapes["blknr"].astype('int64') 
file_path_age = os.path.join(dir_path, 'auxillary','02_Gebäudealter.csv') 
age_df = pd.read_csv(file_path_age)
bldg_age_shapes =  shapes.merge(age_df, on='blknr')

# %%
zone_gdf["geometry"].intersects(bldg_age_shapes["geometry"], align=True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 786    False
# 787    False
# 788    False
# 789    False
# 790    False
# Length: 791, dtype: bool

# %%
list(zone_gdf["category"].value_counts().index)
# Out:
# ['yes',
#  'apartments',
#  'residential',
#  'industrial',
#  'roof',
#  'commercial',
#  'allotment_house',
#  'office',
#  'silo',
#  'school',
#  'hut',
#  'public',
#  'retail',
#  'service',
#  'warehouse',
#  'garages',
#  'church',
#  'construction',
#  'garage',
#  'house',
#  'detached',
#  'manufacture',
#  'kindergarten',
#  'electricity',
#  'toilets',
#  'sports_hall',
#  'houseboat']

# %% [markdown]
# # Archetye mapping
#
# Drop houseboat, detached, shed, train_station, toilets, bridge, construction, garage (s), hut, allotment_house, bungalow, church (?), roof, silo, electricity
#
# Assume yes is apparment.
#
# Compare with: https://wiki.openstreetmap.org/wiki/Key:building

# %%
bldg_to_drop = ["houseboat", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house",  "roof", "silo", "electricity"]

# %%
bldg_type_list = [x for x in list(zone_gdf["category"].value_counts().index) if x not in bldg_to_drop]
bldg_type_list
# Out:
# ['yes',
#  'apartments',
#  'residential',
#  'industrial',
#  'commercial',
#  'office',
#  'school',
#  'public',
#  'retail',
#  'service',
#  'warehouse',
#  'church',
#  'house',
#  'manufacture',
#  'kindergarten',
#  'sports_hall']

# %%
ARCHETYPES = {
     "apartments": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
    "residential": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
      "yes": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
    "industrial": {
        "1860-1978": "NWG_G2_A",
        "1979-2009": "NWG_G2_B",
        "2010-2030": "NWG_G2_C",
    }, 

    "office": {
        "1860-1978": "NWG_1_A",
        "1979-2009": "NWG_1_B",
        "2010-2030": "NWG_1_C",
    },
      "commercial": {
        "1860-1978": "NWG_10_A",
        "1979-2009": "NWG_10_B",
        "2010-2030": "NWG_10_C",
    }, 
    "retail" : {
        "1860-1978": "NWG_9_A",
        "1979-2009": "NWG_9_B",
        "2010-2030": "NWG_9_C",
    }, 
    "warehouse": {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
        "service" : {
             "1860-1978": "NWG_10_A",
        "1979-2009": "NWG_10_B",
        "2010-2030": "NWG_10_C",
        },
        "school": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    },
    "public": {
           "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }, 
     "house": {
        "1860-1918": "SFH_B",
        "1919-1948": "SFH_C",
        "1949-1957": "SFH_D",
        "1958-1968": "SFH_E",
        "1969-1978": "SFH_F",
        '1979-1983' : "SFH_G",
        "1984-1994" : "SFH_H",
        "1995-2001" : "SFH_I",
        "2002-2009" : "SFH_J",
        "2010-2015" : "SFH_K",
        "2016-2030" : "SFH_L",
        
    },"manufacture" : {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
    
        "kindergarten": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    }, 
    "sports_hall": {
        "1860-1978": "NWG_6_A",
        "1979-2009": "NWG_6_B",
        "2010-2030": "NWG_6_C",
    }
    , 
    "church": {
        "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }}

# %%
print(ARCHETYPES.keys())
# Out:
# dict_keys(['apartments', 'residential', 'yes', 'industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public', 'house', 'manufacture', 'kindergarten', 'sports_hall', 'church'])

# %%
gpd.overlay(zone_gdf, bldg_age_shapes, how='intersection')
# Out:
#        Name  height_ag  floors_ag  height_bg  floors_bg descriptio  \
# 0     B1000        2.0          2        3.0          1        NaN
# 1     B1024        1.0          1        3.0          1        NaN
# 2     B1026        4.0          4        3.0          1        NaN
# 3     B1114        6.0          6        3.0          1        NaN
# 4     B1122        3.0          3        3.0          1        NaN
# ...     ...        ...        ...        ...        ...        ...
# 1386  B1779        6.0          6        3.0          1        NaN
# 1387  B1780        5.0          5        3.0          1        NaN
# 1388  B1781        6.0          6        3.0          1        NaN
# 1389  B1782        6.0          6        3.0          1        NaN
# 1390  B1783        5.0          5        3.0          1        NaN
#
#          category       REFERENCE house_no             street  ... x1961_1970  \
# 0          school  OSM - as it is      NaN                NaN  ...        NaN
# 1     sports_hall  OSM - as it is       29    Sömmeringstraße  ...        NaN
# 2          public  OSM - as it is       30  Mierendorffstraße  ...        NaN
# 3      apartments  OSM - as it is      NaN                NaN  ...        NaN
# 4             yes  OSM - as it is       22  Nordhauser Straße  ...        NaN
# ...           ...             ...      ...                ...  ...        ...
# 1386  residential  OSM - as it is      NaN                NaN  ...        NaN
# 1387   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1388   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1389   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1390   apartments  OSM - as it is      NaN                NaN  ...        NaN
#
#       x1971_1980  x1981_1990 x1991_2000 x2001_2010  x2011_2015 ew2015   typ  \
# 0            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 1            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 2            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 3            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 4            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# ...          ...         ...        ...        ...         ...    ...   ...
# 1386         NaN         NaN        NaN        NaN         NaN  300.0  10.0
# 1387         NaN         NaN        NaN        NaN         NaN  323.0  10.0
# 1388         NaN         NaN        NaN        NaN         NaN  691.0  10.0
# 1389         NaN         NaN        NaN        NaN         NaN  691.0  10.0
# 1390         NaN         NaN        NaN        NaN         NaN  336.0  10.0
#
#                                                 typklar  \
# 0                             Neubau-Schule (nach 1945)
# 1                             Neubau-Schule (nach 1945)
# 2                             Neubau-Schule (nach 1945)
# 3                             Neubau-Schule (nach 1945)
# 4                             Neubau-Schule (nach 1945)
# ...                                                 ...
# 1386  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1387  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1388  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1389  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1390  Blockrandbebauung mit Großhöfen (1920er-1940er...
#
#                                                geometry
# 0     POLYGON ((384873.807 5820581.426, 384886.006 5...
# 1     POLYGON ((385043.932 5820642.061, 385043.749 5...
# 2     POLYGON ((384922.724 5820735.592, 384929.001 5...
# 3     POLYGON ((385030.143 5820713.906, 385029.951 5...
# 4     POLYGON ((384966.057 5820720.330, 384966.311 5...
# ...                                                 ...
# 1386  POLYGON ((385451.043 5820715.937, 385446.869 5...
# 1387  POLYGON ((384649.990 5821130.060, 384649.766 5...
# 1388  POLYGON ((384620.571 5821059.758, 384631.713 5...
# 1389  POLYGON ((384622.619 5821008.006, 384622.870 5...
# 1390  POLYGON ((384665.434 5821218.355, 384669.302 5...
#
# [1391 rows x 52 columns]

# %%
def merge_with_max_overlap(gdf_buildings, gdf_blocks):
    # Initialize an empty list to store the result data
    results = []

    # Iterate over each polygon in gdf_buildings
    for index_a, row_a in gdf_buildings.iterrows():
        max_overlap = 0
        best_match = None

        # Compute intersection with each polygon in gdf_blocks and find the max overlap
        for index_b, row_b in gdf_blocks.iterrows():
            intersection = row_a['geometry'].intersection(row_b['geometry'])
            overlap_area = intersection.area

            if overlap_area > max_overlap:
                max_overlap = overlap_area
                best_match = row_b

        # Create a new record for the resulting GeoDataFrame
        if best_match is not None:
            merged_attrs = {**row_a.to_dict(), **best_match.to_dict(), 'overlap_area': max_overlap}
            results.append(merged_attrs)

    # Convert the list of dicts to a GeoDataFrame
    result_gdf = gpd.GeoDataFrame(results, crs=zone_gdf.crs)

    return result_gdf


overlap = merge_with_max_overlap(zone_gdf, bldg_age_shapes)

overlap.head()
# Out:
#     Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0  B1000        2.0          2        3.0          1        NaN      school
# 1  B1001        3.0          3        3.0          1        NaN     service
# 2  B1002        1.0          1        3.0          1        NaN         yes
# 3  B1003        1.0          1        3.0          1        NaN         yes
# 4  B1004        6.0          6        3.0          1        NaN  apartments
#
#         REFERENCE house_no               street  ... x1961_1970  x1971_1980  \
# 0  OSM - as it is      NaN                  NaN  ...        NaN         1.0
# 1  OSM - as it is       10  Lise-Meitner-Straße  ...        NaN         NaN
# 2  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 3  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 4  OSM - as it is      NaN                  NaN  ...        NaN         1.0
#
#    x1981_1990 x1991_2000 x2001_2010 x2011_2015  ew2015   typ  \
# 0         1.0        NaN        NaN        NaN   479.0  13.0
# 1         NaN        NaN        2.0        NaN     NaN  37.0
# 2         NaN        NaN        NaN        NaN   243.0  10.0
# 3         NaN        NaN        NaN        NaN   243.0  10.0
# 4         5.0        NaN        NaN        NaN   476.0  10.0
#
#                                              typklar overlap_area
# 0                          Neubau-Schule (nach 1945)  2526.631853
# 1                        Kleingartenanlage allgemein   547.822059
# 2  Blockrandbebauung mit Großhöfen (1920er-1940er...  2139.055172
# 3  Blockrandbebauung mit Großhöfen (1920er-1940er...   472.988086
# 4  Blockrandbebauung mit Großhöfen (1920er-1940er...  1151.849618
#
# [5 rows x 53 columns]

# %%
overlap.columns
# Out:
# Index(['Name', 'height_ag', 'floors_ag', 'height_bg', 'floors_bg',
#        'descriptio', 'category', 'REFERENCE', 'house_no', 'street', 'postcode',
#        'house_name', 'resi_type', 'city', 'country', 'geometry', 'blknr',
#        'bez_x', 'bezname_x', 'plr_x', 'blktypname_x', 'ewk_x', 'area_x',
#        'datum_x', 'bez_y', 'bezname_y', 'plr_y', 'blktypname_y', 'ewk_y',
#        'area_y', 'datum_y', 'ueberw_dek', 'freistehen', 'doppelhaus',
#        'gereihtes', 'anderertyp', 'x_bis_1900', 'x1901_1910', 'x1911_1920',
#        'x1921_1930', 'x1931_1940', 'x1941_1950', 'x1951_1960', 'x1961_1970',
#        'x1971_1980', 'x1981_1990', 'x1991_2000', 'x2001_2010', 'x2011_2015',
#        'ew2015', 'typ', 'typklar', 'overlap_area'],
#       dtype='object')

# %%
overlap[overlap["Name"] == "B1359"]
# Out:
#       Name  height_ag  floors_ag  height_bg  floors_bg descriptio   category  \
# 358  B1359        1.0          1        3.0          1        NaN  warehouse
#
#           REFERENCE house_no        street  ... x1961_1970  x1971_1980  \
# 358  OSM - as it is       56  Olbersstraße  ...        NaN         NaN
#
#      x1981_1990 x1991_2000 x2001_2010 x2011_2015  ew2015 typ typklar  \
# 358         NaN        NaN        NaN        NaN     NaN NaN     NaN
#
#     overlap_area
# 358   925.788265
#
# [1 rows x 53 columns]

# %%
# Add data for buildings ['B1325', 'B1769'] to the overlap file, then reorder by name 
selected_buildings = zone_gdf[zone_gdf["Name"].isin(['B1325', 'B1769'])]
overlap= gpd.GeoDataFrame(pd.concat([overlap, selected_buildings], ignore_index=True))

overlap = overlap.sort_values(by='Name')

# %%
gdf = zone_gdf
# Calculate bounds for consistent axis limits
xmin, ymin, xmax, ymax = gdf.total_bounds  # Get the bounding box of all geometries

# Extend the bounds a bit for better visualization
xrange = xmax - xmin
yrange = ymax - ymin
xmin -= 0.1 * xrange
xmax += 0.1 * xrange
ymin -= 0.1 * yrange
ymax += 0.1 * yrange


fig, axs = plt.subplots(1, 4, figsize=(20, 8))  

# Plot all Buildings
count_all = gdf.shape[0]
gdf.plot(ax=axs[0], color='blue', edgecolor='k')
axs[0].set_title(f'All Buildings obtained from OSM N = {count_all}')
axs[0].set_xlim(xmin, xmax)
axs[0].set_ylim(ymin, ymax)

# Plot  Residential Buildings
count_type_residential = gdf[gdf['category'].isin(["residential", "apartments", 'house, "bungalow", '])].shape[0]
gdf[gdf['category'].isin(["residential", "apartments", 'house'])].plot(ax=axs[1], color='green', edgecolor='k')
axs[1].set_title(f'Appartment and Residential Buildings N = {count_type_residential}')
axs[1].set_xlim(xmin, xmax)
axs[1].set_ylim(ymin, ymax)

# Plot non Residential Buildings
# Count type B entries
count_type_non_residential = gdf[gdf['category'].isin(['industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall', "church",])].shape[0]
gdf[gdf['category'].isin(['industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall'])].plot(ax=axs[2], color='red', edgecolor='k')
axs[2].set_title(f'Non-Residential Buildings N = {count_type_non_residential}')
axs[2].set_xlim(xmin, xmax)
axs[2].set_ylim(ymin, ymax)

# Plot non valid Building Types
count_type_invalid = gdf[gdf['category'].isin(["houseboat", "yes", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house", "roof", "silo", "electricity"])].shape[0]
gdf[gdf['category'].isin(["houseboat", "yes", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house", "bungalow", "church", "roof", "silo", "electricity"])].plot(ax=axs[3], color='yellow', edgecolor='k')
axs[3].set_title(f'Invalid Building Types N = {count_type_invalid}')
axs[3].set_xlim(xmin, xmax)
axs[3].set_ylim(ymin, ymax)

# Remove the axis for a cleaner look and adjust for space between plots
for ax in axs:
    ax.axis('off')

# Common header
plt.suptitle('Visualization of Open Street Map Building Types', fontsize=16)

# Show plot
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the common header
plt.show()

# %%
def merge_with_max_overlap(gdf_buildings, gdf_blocks):
    # Initialize an empty list to store the result data
    results = []

    # Iterate over each polygon in gdf_buildings
    for index_a, row_a in gdf_buildings.iterrows():
        max_overlap = 0
        best_match = None
        best_match_attrs = None

        # Compute intersection with each polygon in gdf_blocks and find the max overlap
        for index_b, row_b in gdf_blocks.iterrows():
            intersection = row_a['geometry'].intersection(row_b['geometry'])
            overlap_area = intersection.area

            if overlap_area > max_overlap:
                max_overlap = overlap_area
                best_match = row_b
                # Exclude geometry from row_b to preserve the geometry from row_a
                best_match_attrs = {k: v for k, v in row_b.items() if k != 'geometry'}

        # Create a new record for the resulting GeoDataFrame, preserving row_a's geometry
        if best_match is not None:
            merged_attrs = {**row_a.to_dict(), **best_match_attrs, 'overlap_area': max_overlap}
            results.append(merged_attrs)

    # Convert the list of dicts to a GeoDataFrame
    result_gdf = gpd.GeoDataFrame(results, crs=gdf_buildings.crs)  # Ensure the CRS is taken from gdf_buildings

    return result_gdf

# Example usage:
# Assuming zone_gdf and bldg_age_shapes are your GeoDataFrames loaded beforehand
overlap_reduced = merge_with_max_overlap(zone_gdf, bldg_age_shapes)

# Print the first few rows of the resulting GeoDataFrame
overlap_reduced.head()
# Out:
#     Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0  B1000        2.0          2        3.0          1        NaN      school
# 1  B1001        3.0          3        3.0          1        NaN     service
# 2  B1002        1.0          1        3.0          1        NaN         yes
# 3  B1003        1.0          1        3.0          1        NaN         yes
# 4  B1004        6.0          6        3.0          1        NaN  apartments
#
#         REFERENCE house_no               street  ... x1961_1970  x1971_1980  \
# 0  OSM - as it is      NaN                  NaN  ...        NaN         1.0
# 1  OSM - as it is       10  Lise-Meitner-Straße  ...        NaN         NaN
# 2  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 3  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 4  OSM - as it is      NaN                  NaN  ...        NaN         1.0
#
#    x1981_1990 x1991_2000 x2001_2010 x2011_2015  ew2015   typ  \
# 0         1.0        NaN        NaN        NaN   479.0  13.0
# 1         NaN        NaN        2.0        NaN     NaN  37.0
# 2         NaN        NaN        NaN        NaN   243.0  10.0
# 3         NaN        NaN        NaN        NaN   243.0  10.0
# 4         5.0        NaN        NaN        NaN   476.0  10.0
#
#                                              typklar overlap_area
# 0                          Neubau-Schule (nach 1945)  2526.631853
# 1                        Kleingartenanlage allgemein   547.822059
# 2  Blockrandbebauung mit Großhöfen (1920er-1940er...  2139.055172
# 3  Blockrandbebauung mit Großhöfen (1920er-1940er...   472.988086
# 4  Blockrandbebauung mit Großhöfen (1920er-1940er...  1151.849618
#
# [5 rows x 53 columns]

# %%
# Ingore yes here, due to diversity of building types
gdf = overlap.copy()
# Calculate bounds for consistent axis limits
xmin, ymin, xmax, ymax = gdf.total_bounds  # Get the bounding box of all geometries

# Extend the bounds a bit for better visualization
xrange = xmax - xmin
yrange = ymax - ymin
xmin -= 0.1 * xrange
xmax += 0.1 * xrange
ymin -= 0.1 * yrange
ymax += 0.1 * yrange

# Plot setup
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # Horizontal layout with 3 plots

# Plot all geometries
gdf.plot(ax=axs[0], color='blue', edgecolor='k')
axs[0].set_title('All Block data obtained from munciaplity')
axs[0].set_xlim(xmin, xmax)
axs[0].set_ylim(ymin, ymax)

# Plot types A and C
gdf[gdf['ueberw_dek'].isin(['2001-2010', '1901-1910', '1951-1960', '2011-2015', 'bis 1900', '1921-1930', '1981-1990', '1931-1940'])].plot(ax=axs[1], color='green', edgecolor='k')
axs[1].set_title('Predominant residential building age group given per block')
axs[1].set_xlim(xmin, xmax)
axs[1].set_ylim(ymin, ymax)

# Plot type B
gdf[gdf['ueberw_dek'].isin(["gemischte Baualtersklasse"])].plot(ax=axs[2], color='red', edgecolor='k')
axs[2].set_title('No predominant residential building age')
axs[2].set_xlim(xmin, xmax)
axs[2].set_ylim(ymin, ymax)

# Remove the axis for a cleaner look and adjust for space between plots
for ax in axs:
    ax.axis('off')

# Common header
plt.suptitle('Visualization of predominant building age groups', fontsize=16)

# Show plot
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the common header
plt.show()

# %%
def average_year_from_range(year_range):
    # This function extracts the start and end years from a range, calculates the average, and returns it as an integer
    # "gemischte"
    print(year_range, type(year_range))
    if '-' in year_range:
        start_year, end_year = year_range.split('-')
        average_year = (int(start_year) + int(end_year)) // 2
        return average_year
    elif year_range == "gemischte Baualtersklasse":
        return None 
    elif year_range == "bis 1900": 
        return 1900
    elif year_range == "NaN":
        return None 

    return int(year_range)  # Handles cases where the year is not a range but a single year


def find_year_range(bldg_type, year):
    # function determines the year range that a given year falls into based on its categorization  
    if bldg_type in ["yes", "apartments", "residential", "house"] and isinstance(year, int):
        #determine bldg age groups on years
        if 1860 <= year <= 1918:
            return "1860-1918"
        elif 1919 <= year <= 1948:
            return "1919-1948"
        elif 1949 <= year <= 1957:
            return "1949-1957"
        elif 1958 <= year <= 1968:
            return "1958-1968"
        elif 1969 <= year <= 1978:
            return "1969-1978"
        elif 1979 <= year <= 2009:
            return None
        else:
            return None 
    else:
        if isinstance(year, int):
            # Non Residential building groups
            if 1860 <= year <= 1978:
                return "1860-1978"
            elif 1979 <= year <= 2009:
                return "1979-2009"
            elif 2010 <= year <= 2030:
                return "2010-2030"
            else:
                return None
        else:
            return None

def match_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        return None 
    year_range = find_year_range(bldg_type, average_year)
    if bldg_type in ARCHETYPES and year_range in ARCHETYPES[bldg_type]:
        return ARCHETYPES[bldg_type][year_range]
    return None


overlap["ARCHETYPE"] = overlap.apply(lambda row: match_building_type(row['category'], row['ueberw_dek']), axis=1)
# Out:
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# 1921-1930 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1931-1940 <class 'str'>
# 1931-1940 <class 'str'>
# 1931-1940 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1951-1960 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# 2011-2015 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# nan <class 'float'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 2011-2015 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 2001-2010 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1981-1990 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1921-1930 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# nan <class 'float'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan <class 'float'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>

# %%
# Create folder for modelling based on suggestions 
archetype = "GER_Updated"
year = "2020"
path_to_new_scenario = os.path.join(project_folder, 'Baseline', f'{year}') # create the destination path for copying the baseline scenario
path_to_baseline = os.path.join(project_folder, 'Baseline', year)
try:
    shutil.copytree(path_to_baseline, path_to_new_scenario)
except WindowsError:
    pass

# %%
# map archetypes based on average year of block and building type 
archetype_path = os.path.join(project_folder, 'Baseline', f'{year}', "inputs", "building-properties", "typology.dbf")
archetype_file = gpd.read_file(archetype_path)
#archetype_file["STANDARD"] = archetype
archetype_file
# Out:
#       Name STANDARD    YEAR    1ST_USE  1ST_USE_R 2ND_USE  2ND_USE_R 3RD_USE  \
# 0    B1000    SFH_C  1934.0     SCHOOL        1.0    NONE        0.0    NONE
# 1    B1001    SFH_C  1934.0    PARKING        1.0    NONE        0.0    NONE
# 2    B1002    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 3    B1003    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 4    B1004    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# ..     ...      ...     ...        ...        ...     ...        ...     ...
# 786  B1786    SFH_C  1934.0     OFFICE        1.0    NONE        0.0    NONE
# 787  B1787    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 788  B1788    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 789  B1789    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 790  B1790    SFH_C  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
#
#      3RD_USE_R     REFERENCE geometry
# 0          0.0  OSM - median     None
# 1          0.0  OSM - median     None
# 2          0.0  OSM - median     None
# 3          0.0  OSM - median     None
# 4          0.0  OSM - median     None
# ..         ...           ...      ...
# 786        0.0  OSM - median     None
# 787        0.0  OSM - median     None
# 788        0.0  OSM - median     None
# 789        0.0  OSM - median     None
# 790        0.0  OSM - median     None
#
# [791 rows x 11 columns]

# %%
archetype_file[archetype_file["Name"] == "B1359"]
# Out:
#       Name STANDARD    YEAR  1ST_USE  1ST_USE_R 2ND_USE  2ND_USE_R 3RD_USE  \
# 359  B1359    SFH_C  1934.0  PARKING        1.0    NONE        0.0    NONE
#
#      3RD_USE_R     REFERENCE geometry
# 359        0.0  OSM - median     None

# %%
# Map the archetypes
archetype_file["STANDARD"] = overlap["ARCHETYPE"]

# %%
# Get the list of all builidngs that are modeled
# gdf['category'].isin(["residential", "apartments", 'house, "bungalow", '
'industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall', "church", 
list_buildings = selection_gdf[(~selection_gdf["category"].isin(bldg_to_drop)) & (selection_gdf["area"] > 40)]["Name"].tolist()

# %%
# Get all Buildings, where an archetype was assigned
archetype_path = os.path.join(project_folder, 'Baseline', f'{year}', "inputs", "building-properties", "typology.dbf")
typology_dbf = gpd.read_file(archetype_path)

# %%
list_assigned_standard = typology_dbf[typology_dbf["STANDARD"].notnull()]["Name"].tolist()

# %%
list_assigned_standard
# Out:
# ['B1000',
#  'B1001',
#  'B1002',
#  'B1003',
#  'B1004',
#  'B1005',
#  'B1006',
#  'B1007',
#  'B1008',
#  'B1009',
#  'B1010',
#  'B1011',
#  'B1012',
#  'B1013',
#  'B1014',
#  'B1015',
#  'B1016',
#  'B1017',
#  'B1018',
#  'B1019',
#  'B1020',
#  'B1021',
#  'B1022',
#  'B1023',
#  'B1024',
#  'B1025',
#  'B1026',
#  'B1027',
#  'B1028',
#  'B1029',
#  'B1030',
#  'B1031',
#  'B1032',
#  'B1033',
#  'B1034',
#  'B1035',
#  'B1036',
#  'B1037',
#  'B1038',
#  'B1039',
#  'B1040',
#  'B1041',
#  'B1042',
#  'B1043',
#  'B1044',
#  'B1045',
#  'B1046',
#  'B1047',
#  'B1048',
#  'B1049',
#  'B1050',
#  'B1051',
#  'B1052',
#  'B1053',
#  'B1054',
#  'B1055',
#  'B1056',
#  'B1057',
#  'B1058',
#  'B1059',
#  'B1060',
#  'B1061',
#  'B1062',
#  'B1063',
#  'B1064',
#  'B1065',
#  'B1066',
#  'B1067',
#  'B1068',
#  'B1069',
#  'B1070',
#  'B1071',
#  'B1072',
#  'B1073',
#  'B1074',
#  'B1075',
#  'B1076',
#  'B1077',
#  'B1078',
#  'B1079',
#  'B1080',
#  'B1081',
#  'B1082',
#  'B1083',
#  'B1084',
#  'B1085',
#  'B1086',
#  'B1087',
#  'B1088',
#  'B1089',
#  'B1090',
#  'B1091',
#  'B1092',
#  'B1093',
#  'B1094',
#  'B1095',
#  'B1096',
#  'B1097',
#  'B1098',
#  'B1099',
#  'B1100',
#  'B1101',
#  'B1102',
#  'B1103',
#  'B1104',
#  'B1105',
#  'B1106',
#  'B1107',
#  'B1108',
#  'B1109',
#  'B1110',
#  'B1111',
#  'B1112',
#  'B1113',
#  'B1114',
#  'B1115',
#  'B1116',
#  'B1117',
#  'B1118',
#  'B1119',
#  'B1120',
#  'B1121',
#  'B1122',
#  'B1123',
#  'B1124',
#  'B1125',
#  'B1126',
#  'B1127',
#  'B1128',
#  'B1129',
#  'B1130',
#  'B1131',
#  'B1132',
#  'B1133',
#  'B1134',
#  'B1710',
#  'B1711',
#  'B1712',
#  'B1713',
#  'B1714',
#  'B1715',
#  'B1716',
#  'B1717',
#  'B1718',
#  'B1719',
#  'B1720',
#  'B1721',
#  'B1722',
#  'B1723',
#  'B1724',
#  'B1725',
#  'B1726',
#  'B1727',
#  'B1728',
#  'B1729',
#  'B1730',
#  'B1731',
#  'B1732',
#  'B1733',
#  'B1734',
#  'B1735',
#  'B1736',
#  'B1737',
#  'B1738',
#  'B1739',
#  'B1740',
#  'B1741',
#  'B1742',
#  'B1743',
#  'B1744',
#  'B1745',
#  'B1746',
#  'B1747',
#  'B1748',
#  'B1749',
#  'B1750',
#  'B1751',
#  'B1752',
#  'B1753',
#  'B1754',
#  'B1755',
#  'B1756',
#  'B1757',
#  'B1758',
#  'B1759',
#  'B1760',
#  'B1761',
#  'B1762',
#  'B1763',
#  'B1764',
#  'B1765',
#  'B1766',
#  'B1767',
#  'B1768',
#  'B1769',
#  'B1770',
#  'B1771',
#  'B1772',
#  'B1773',
#  'B1774',
#  'B1775',
#  'B1776',
#  'B1777',
#  'B1778',
#  'B1779',
#  'B1780',
#  'B1781',
#  'B1782',
#  'B1783',
#  'B1784',
#  'B1785',
#  'B1786',
#  'B1787',
#  'B1788',
#  'B1789',
#  'B1790']

# %% [markdown]
# # Baseline

# %%
# Create Default Baseline Scenarios for all years 
years = ["2020", "2021", "2022"]
config = cea.config.Configuration()
for year in years: 
    path_to_new_scenario = os.path.join(project_folder, 'DefaultModel', f'{year}') 
    path_to_baseline = os.path.join(project_folder, 'Baseline', f'{year}')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
        config.project = os.path.join(project_folder, 'DefaultModel')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE"
        config.save()
    except WindowsError:
        pass

# %%
# Model buildings in standard

# %%
# Assumptions
# For all residential building types, the MULTI_RES is assigned
# For office (NWG1), OFFICE is assigned
# For University (NWG2), UNIVERSITY is assigned
# For IWU Health and care buildings (NWG3), HEALTH is assigned
# For School (NWG4), SCHOOL is assigned
# For culture (NWG 5), MUSEUM is assigned
# For sports facilities (NWG 6), GYM is assigned
# For hotels, restaurants e.g. (NWG 7), HOTEL is assigned
# For all production, workshop buildings (NWG 8), INDUSTRIAL is assigned
# For all trade buildings (NWG 9), RETAIL is assigned
# For all technicals and uitlity buildings (NWG 10, ), INDUSTRIAL is assigned
# For all IWU Transport (NWG 11), PARKING is assigned
# For all generalized Service buldings (NWG G1), OFFICE is assigned
# For all generalized industrial (NWG G2) INDUSTRIAL is assigned

USE_DICT = {
    'SFH': "SINGLE_RES",
    'AB' : "MULTI_RES",
    'MFH': "MULTI_RES",
    'TH': "SINGLE_RES",
    "HR" : "MULTI_RES",
    'NWG_1' : "OFFICE",
    "NWG_2" : "UNIVERSITY",
    "NWG_3" : "HEALTH",
    "NWG_4" : "SCHOOL",
    "NWG_5" : "MUSEUM",
    "NWG_6" : "GYM",
    "NWG_7" : "HOTEL",
    "NWG_8" : "INDUSTRIAL",
    "NWG_9" : "RETAIL",
    "NWG_10" : "INDUSTRIAL",
    "NWG_11" : "PARKING",
    "NWG_G1" : "OFFICE",
    "NWG_G2" : "INDUSTRIAL",

   
}

# Sort the keys by length in descending order to match longer keys first
keys = sorted(USE_DICT.keys(), key=len, reverse=True)

# Create a regex pattern to match any of the keys at the start of the string
pattern = r'^(' + '|'.join(map(re.escape, keys)) + ')'

# Extract the key using the regex pattern and map to USE_DICT
overlap['1ST_USE'] = overlap['ARCHETYPE'].str.extract(pattern)[0].map(USE_DICT)

overlap_copy = overlap.copy()

# Ensure no duplicate 'Name' values in overlap
overlap_copy = overlap_copy.drop_duplicates(subset='Name')

# Create a dictionary from overlap for fast lookup
overlap_dict = overlap_copy.set_index('Name').to_dict(orient='index')


# Custom function to update the STANDARD, 1ST_USE and YEAR columns
def update_columns(row):
    if row['Name'] in overlap_dict:
        standard = overlap_dict[row['Name']]['ARCHETYPE']
        first_use = overlap_dict[row['Name']]['1ST_USE']
        
        return pd.Series([standard, first_use])
    return pd.Series([row['STANDARD'], row['1ST_USE']])

# %% [markdown]
# ## Baseline Simulation

# %%
# Build Baselines for all years
# Just consider the buildings that have been assigned a standard by simply mapping
# Name this default model
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    #config.data_helper.region = 'DE'
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'DefaultModel', f'{year}') 
    path_to_baseline = os.path.join(project_folder, 'Baseline', f'{year}')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
    except WindowsError:
        pass 
    # Set archetypes to previously identifed archetypes
    config.project = os.path.join(project_folder, 'DefaultModel')
    config.scenario_name = f'{year}'
    config.general.database_path = "DE"
    if os.path.exists(os.path.join(path_to_new_scenario, "outputs", "data", "demand", "Total_demand.csv")):
        continue

    
    archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
    archetype_file = gpd.read_file(archetype_path)
    archetype_file [['STANDARD', '1ST_USE']] = archetype_file.apply(update_columns, axis=1)
    
    no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()

    archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    archetype_file = archetype_file[archetype_file['Name'].isin(archetype_buildings)]
    archetype_file.to_file(archetype_path)
    zone_path = os.path.join(path_to_new_scenario, "inputs", "building-geometry", "zone.shp")
    zone_gdf = gpd.read_file(zone_path)
    #zone_gdf.drop(zone_gdf[zone_gdf['Name'].isin(no_archetype_buildings)], inplace=True)
    zone_gdf = zone_gdf[zone_gdf['Name'].isin(archetype_buildings)]
    zone_gdf.to_file(zone_path)
    
    archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
# Calculation of terrain intersection for building 68 completed out of 365
# Calculation of terrain intersection for building 69 completed out of 365
# Calculation of terrain intersection for building 70 completed out of 365
# Calculation of terrain intersection for building 71 completed out of 365Calculation of terrain intersection for building 72 completed out of 365
#
# Calculation of terrain intersection for building 73 completed out of 365
# Calculation of terrain intersection for building 74 completed out of 365
# Calculation of terrain intersection for building 75 completed out of 365
# Calculation of terrain intersection for building 76 completed out of 365
# Calculation of terrain intersection for building 77 completed out of 365
# Calculation of terrain intersection for building 78 completed out of 365
# Calculation of terrain intersection for building 79 completed out of 365Calculation of terrain intersection for building 80 completed out of 365
#
# Calculation of terrain intersection for building 81 completed out of 365Calculation of terrain intersection for building 82 completed out of 365
#
# Calculation of terrain intersection for building 83 completed out of 365
# Calculation of terrain intersection for building 84 completed out of 365
# Calculation of terrain intersection for building 85 completed out of 365
# Calculation of terrain intersection for building 86 completed out of 365
# Calculation of terrain intersection for building 87 completed out of 365
# Calculation of terrain intersection for building 88 completed out of 365
# Calculation of terrain intersection for building 89 completed out of 365
# Calculation of terrain intersection for building 90 completed out of 365
# Calculation of terrain intersection for building 91 completed out of 365
# Calculation of terrain intersection for building 92 completed out of 365
# Calculation of terrain intersection for building 93 completed out of 365
# Calculation of terrain intersection for building 94 completed out of 365
# Calculation of terrain intersection for building 95 completed out of 365
# Calculation of terrain intersection for building 96 completed out of 365
# Calculation of terrain intersection for building 97 completed out of 365
# Calculation of terrain intersection for building 98 completed out of 365Calculation of terrain intersection for building 99 completed out of 365
#
# Calculation of terrain intersection for building 100 completed out of 365
# Calculation of terrain intersection for building 101 completed out of 365
# Calculation of terrain intersection for building 102 completed out of 365Calculation of terrain intersection for building 103 completed out of 365
#
# Calculation of terrain intersection for building 104 completed out of 365
# Calculation of terrain intersection for building 105 completed out of 365
# Calculation of terrain intersection for building 106 completed out of 365
# Calculation of terrain intersection for building 107 completed out of 365
# Calculation of terrain intersection for building 108 completed out of 365
# Calculation of terrain intersection for building 109 completed out of 365
# Calculation of terrain intersection for building 110 completed out of 365
# Calculation of terrain intersection for building 111 completed out of 365
# Calculation of terrain intersection for building 112 completed out of 365
# Calculation of terrain intersection for building 114 completed out of 365Calculation of terrain intersection for building 113 completed out of 365
#
# Calculation of terrain intersection for building 115 completed out of 365
# Calculation of terrain intersection for building 116 completed out of 365
# Calculation of terrain intersection for building 117 completed out of 365
# Calculation of terrain intersection for building 118 completed out of 365
# Calculation of terrain intersection for building 119 completed out of 365Calculation of terrain intersection for building 120 completed out of 365
#
# Calculation of terrain intersection for building 121 completed out of 365
# Calculation of terrain intersection for building 122 completed out of 365Calculation of terrain intersection for building 123 completed out of 365
#
# Calculation of terrain intersection for building 124 completed out of 365
# Calculation of terrain intersection for building 125 completed out of 365
# Calculation of terrain intersection for building 126 completed out of 365
# Calculation of terrain intersection for building 127 completed out of 365
# Calculation of terrain intersection for building 128 completed out of 365
# Calculation of terrain intersection for building 129 completed out of 365
# Calculation of terrain intersection for building 130 completed out of 365
# Calculation of terrain intersection for building 131 completed out of 365
# Calculation of terrain intersection for building 196 completed out of 365
# Calculation of terrain intersection for building 197 completed out of 365
# Calculation of terrain intersection for building 198 completed out of 365
# Calculation of terrain intersection for building 199 completed out of 365
# Calculation of terrain intersection for building 200 completed out of 365
# Calculation of terrain intersection for building 201 completed out of 365
# Calculation of terrain intersection for building 202 completed out of 365
# Calculation of terrain intersection for building 203 completed out of 365
# Calculation of terrain intersection for building 204 completed out of 365
# Calculation of terrain intersection for building 205 completed out of 365
# Calculation of terrain intersection for building 206 completed out of 365
# Calculation of terrain intersection for building 207 completed out of 365
# Calculation of terrain intersection for building 209 completed out of 365Calculation of terrain intersection for building 210 completed out of 365Calculation of terrain intersection for building 208 completed out of 365
#
#
# Calculation of terrain intersection for building 211 completed out of 365
# Calculation of terrain intersection for building 212 completed out of 365
# Calculation of terrain intersection for building 213 completed out of 365
# Calculation of terrain intersection for building 214 completed out of 365
# Calculation of terrain intersection for building 215 completed out of 365
# Calculation of terrain intersection for building 216 completed out of 365
# Calculation of terrain intersection for building 217 completed out of 365
# Calculation of terrain intersection for building 218 completed out of 365
# Calculation of terrain intersection for building 219 completed out of 365
# Calculation of terrain intersection for building 220 completed out of 365
# Calculation of terrain intersection for building 221 completed out of 365Calculation of terrain intersection for building 222 completed out of 365
#
# Calculation of terrain intersection for building 223 completed out of 365
# Calculation of terrain intersection for building 224 completed out of 365
# Calculation of terrain intersection for building 225 completed out of 365
# Calculation of terrain intersection for building 226 completed out of 365
# Calculation of terrain intersection for building 227 completed out of 365
# Calculation of terrain intersection for building 228 completed out of 365Calculation of terrain intersection for building 229 completed out of 365
#
# Calculation of terrain intersection for building 230 completed out of 365
# Calculation of terrain intersection for building 231 completed out of 365Calculation of terrain intersection for building 232 completed out of 365
#
# Calculation of terrain intersection for building 233 completed out of 365
# Calculation of terrain intersection for building 234 completed out of 365
# Calculation of terrain intersection for building 235 completed out of 365
# Calculation of terrain intersection for building 236 completed out of 365
# Calculation of terrain intersection for building 237 completed out of 365
# Calculation of terrain intersection for building 238 completed out of 365Calculation of terrain intersection for building 239 completed out of 365
#
# Calculation of terrain intersection for building 240 completed out of 365
# Calculation of terrain intersection for building 241 completed out of 365
# Calculation of terrain intersection for building 242 completed out of 365
# Calculation of terrain intersection for building 243 completed out of 365
# Calculation of terrain intersection for building 244 completed out of 365
# Calculation of terrain intersection for building 245 completed out of 365
# Calculation of terrain intersection for building 246 completed out of 365
# Calculation of terrain intersection for building 247 completed out of 365
# Calculation of terrain intersection for building 248 completed out of 365
# Calculation of terrain intersection for building 249 completed out of 365
# Calculation of terrain intersection for building 250 completed out of 365
# Calculation of terrain intersection for building 252 completed out of 365Calculation of terrain intersection for building 251 completed out of 365
#
# Calculation of terrain intersection for building 253 completed out of 365
# Calculation of terrain intersection for building 254 completed out of 365
# Calculation of terrain intersection for building 255 completed out of 365
# Calculation of terrain intersection for building 256 completed out of 365
# Calculation of terrain intersection for building 257 completed out of 365Calculation of terrain intersection for building 258 completed out of 365
#
# Calculation of terrain intersection for building 259 completed out of 365
# Building No. 300 completed out of 365: B1471
# Building No. 301 completed out of 365: B1469
# Building No. 302 completed out of 365: B1465
# Building No. 303 completed out of 365: B1467
# Building No. 304 completed out of 365: B1790
# Building No. 305 completed out of 365: B1429
# Building No. 306 completed out of 365: B1782
# Building No. 307 completed out of 365: B1717
# Building No. 308 completed out of 365: B1446
# Building No. 309 completed out of 365: B1715Building No. 310 completed out of 365: B1505
#
# Building No. 311 completed out of 365: B1509
# Building No. 312 completed out of 365: B1511
# Building No. 313 completed out of 365: B1486
# Building No. 314 completed out of 365: B1501
# Building No. 315 completed out of 365: B1495
# Building No. 316 completed out of 365: B1507
# Building No. 317 completed out of 365: B1780
# Building No. 318 completed out of 365: B1788
# Building No. 319 completed out of 365: B1786
# Building No. 320 completed out of 365: B1784
# Building No. 321 completed out of 365: B1719
# Building No. 322 completed out of 365: B1493
# Building No. 323 completed out of 365: B1513
# Building No. 324 completed out of 365: B1515
# Building No. 325 completed out of 365: B1388
# Building No. 326 completed out of 365: B1417
# Building No. 327 completed out of 365: B1420
# Building No. 328 completed out of 365: B1394
# Building No. 329 completed out of 365: B1392
# Building No. 330 completed out of 365: B1390
# Building No. 331 completed out of 365: B1404
# Building No. 332 completed out of 365: B1402
# Building No. 333 completed out of 365: B1439
# Building No. 334 completed out of 365: B1779
# Building No. 335 completed out of 365: B1426
# Building No. 336 completed out of 365: B1424
# Building No. 337 completed out of 365: B1428
# Building No. 338 completed out of 365: B1714
# Building No. 339 completed out of 365: B1468
# Building No. 340 completed out of 365: B1464
# Building No. 341 completed out of 365: B1474
# Building No. 342 completed out of 365: B1478
# Building No. 343 completed out of 365: B1470
# Building No. 344 completed out of 365: B1462
# Building No. 345 completed out of 365: B1718Building No. 346 completed out of 365: B1716
#
# Building No. 347 completed out of 365: B1508
# Building No. 348 completed out of 365: B1472
# Building No. 349 completed out of 365: B1466
# Building No. 350 completed out of 365: B1460
# Building No. 351 completed out of 365: B1506
# Building No. 352 completed out of 365: B1783
# Building No. 353 completed out of 365: B1490
# Building No. 354 completed out of 365: B1781
# Building No. 355 completed out of 365: B1510
# Building No. 356 completed out of 365: B1500
# Building No. 357 completed out of 365: B1789
# Building No. 358 completed out of 365: B1504
# Building No. 359 completed out of 365: B1787
# Building No. 360 completed out of 365: B1494
# Building No. 361 completed out of 365: B1512
# Building No. 362 completed out of 365: B1785
# Building No. 363 completed out of 365: B1514
# Building No. 364 completed out of 365: B1770
# Building No. 365 completed out of 365: B1709
# done - time elapsed: 135.2 seconds

# %% [markdown]
# # Benchmark

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'Benchmark', f'{year}') 
    path_to_baseline = os.path.join(project_folder, 'Baseline', f'{year}')
    try:
        shutil.copytree( path_to_baseline, path_to_new_scenario)
        config.project = os.path.join(project_folder, 'Benchmark')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE"
        config.save()
    except WindowsError:
        pass

# %%
# Model Standard 
# Model Year 
# Model 1st_Use 
shape_gpd = gpd.read_file(os.path.join(project_folder, 'Benchmark', '2020', "inputs", "building-geometry", "zone.shp"))
type_gpd = gpd.read_file(os.path.join(project_folder, 'Benchmark', '2020', "inputs", "building-properties", "typology.dbf"))

# %%
# Visualize building that could not be assigned an archetype
no_archetype = overlap[overlap["ARCHETYPE"].isnull()]["Name"].tolist()
shape_gpd[shape_gpd["Name"].isin(no_archetype)].plot()
# Out:
# <Axes: >

# %%
# Analzye the building types that could not be assigned an archetype
shape_gpd[shape_gpd["Name"].isin(no_archetype)].category.value_counts()
# Out:
# category
# yes            250
# apartments      26
# residential      5
# Name: count, dtype: int64

# %%
shape_gpd[shape_gpd["Name"].isin(no_archetype) & shape_gpd["category"].isin(["yes"])].plot()
# Out:
# <Axes: >

# %%
# After visual inspection, yes it it mostly buildings that are related to an type, e.g. the sheds. 
# Get rid of all building smaller than 100m2
shape_gpd["area"] = shape_gpd["geometry"].area
bigger_shape = shape_gpd[shape_gpd["area"] > 100]
bigger_shape[bigger_shape["category"].isin(["yes"])].plot()
# Out:
# <Axes: >

# %%
shape_gpd[shape_gpd["area"] > 100 ].category.value_counts()
# Out:
# category
# apartments     271
# yes             63
# residential     51
# industrial       8
# commercial       6
# office           5
# school           4
# retail           4
# public           4
# service          2
# house            2
# sports_hall      1
# warehouse        1
# houseboat        1
# church           1
# Name: count, dtype: int64

# %%
small_buildings = shape_gpd[shape_gpd['area'] < 100]['Name'].tolist()

# %%
# Calibration with Archetypes
# For checking different renovation status
# Random Assesment of year for Non Residential Buildings
renovation_arechteypes= ["" , "NR", "AR"] 
non_residential_variations = ["_A", "_B", "_C"]

# %%
# For AB type buildings after 1978 no data is available
# Model them as MF 

def find__enhanced_year_range(bldg_type, year):
    # function determines the year range that a given year falls into based on its categorization  
    if bldg_type in ["yes", "apartments", "residential", "house", "apartment"] and isinstance(year, int):
        #determine bldg age groups on years
        if year == "bis 1900":
            return "1860-1918"
        if 1860 <= year <= 1918:
            return "1860-1918"
        elif 1919 <= year <= 1948:
            return "1919-1948"
        elif 1949 <= year <= 1957:
            return "1949-1957"
        elif 1958 <= year <= 1968:
            return "1958-1968"
        elif 1969 <= year <= 1978:
            return "1969-1978"
        elif 1979 <= year <= 1983:
            return "1979-1983"
        elif 1984 <= year <= 1994:
            return "1984-1994"
        elif 1995 <= year <= 2001:
            return "1995-2001"
        elif 2002 <= year <= 2009:
            return "2002-2009"
        elif 2010 <= year <= 2015:
            return "2010-2015"
        elif 2016 <= year <= 2030:
            return "2016-2030"
        else:
            return None
    else:
        if isinstance(year, int):
            # Non Residential building groups
            if 1860 <= year <= 1978:
                return "1860-1978"
            elif 1979 <= year <= 2009:
                return "1979-2009"
            elif 2010 <= year <= 2030:
                return "2010-2030"
            else:
                return None
        else:
            return None

        
# ADD MFH Archetypes for Apparments constructed after 1978
ENHANCED_ARCHETYPES = {
        "2010-2030": "NWG_4_C",
    }, 
    "sports_hall": {
        "1860-1978": "NWG_6_A",
        "1979-2009": "NWG_6_B",
        "2010-2030": "NWG_6_C",
    }
    , 
    "church": {
        "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }}

# %%
def match_enhanced_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        print(year)
        return None 
    year_range = find__enhanced_year_range(bldg_type, average_year)
    if bldg_type in ENHANCED_ARCHETYPES and year_range in ENHANCED_ARCHETYPES[bldg_type]:
        return ENHANCED_ARCHETYPES[bldg_type][year_range]
    return None


overlap["ENHANCED_ARCHETYPE"] = overlap.apply(lambda row: match_enhanced_building_type(row['category'], row['ueberw_dek']), axis=1)
# Out:
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# 1921-1930 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1931-1940 <class 'str'>
# 1931-1940 <class 'str'>
# 1931-1940 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1951-1960 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# 2011-2015 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# bis 1900 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# nan <class 'float'>
# nan
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 2011-2015 <class 'str'>
# 1921-1930 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 2001-2010 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# 1981-1990 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1901-1910 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# bis 1900 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1981-1990 <class 'str'>
# 1921-1930 <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# gemischte Baualtersklasse <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1951-1960 <class 'str'>
# 1951-1960 <class 'str'>
# nan <class 'float'>
# nan
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2011-2015 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2011-2015 <class 'str'>
# 1901-1910 <class 'str'>
# nan <class 'float'>
# nan
# 2001-2010 <class 'str'>
# nan <class 'float'>
# nan
# nan <class 'float'>
# nan
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 2001-2010 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1921-1930 <class 'str'>
# 1921-1930 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>
# 1901-1910 <class 'str'>

# %%
overlap[overlap["ueberw_dek"] == "gemischte Baualtersklasse"][['x_bis_1900', 'x1901_1910', 'x1911_1920', 'x1921_1930', 'x1931_1940', 'x1941_1950', 'x1951_1960', 'x1961_1970', 'x1971_1980', 'x1981_1990', 'x1991_2000', 'x2001_2010', 'x2011_2015']]
# Out:
#      x_bis_1900  x1901_1910  x1911_1920  x1921_1930  x1931_1940  x1941_1950  \
# 41          3.0         4.0         4.0         2.0         NaN         NaN
# 42          3.0         4.0         4.0         2.0         NaN         NaN
# 43          3.0         4.0         4.0         2.0         NaN         NaN
# 44          3.0         4.0         4.0         2.0         NaN         NaN
# 45          3.0         4.0         4.0         2.0         NaN         NaN
# 46          3.0         4.0         4.0         2.0         NaN         NaN
# 47          3.0         4.0         4.0         2.0         NaN         NaN
# 48          3.0         4.0         4.0         2.0         NaN         NaN
# 49          3.0         4.0         4.0         2.0         NaN         NaN
# 50          3.0         4.0         4.0         2.0         NaN         NaN
# 51          3.0         4.0         4.0         2.0         NaN         NaN
# 52          3.0         4.0         4.0         2.0         NaN         NaN
# 205         7.0         2.0         7.0         NaN         NaN         1.0
# 208         7.0         2.0         7.0         NaN         NaN         1.0
# 211         7.0         2.0         7.0         NaN         NaN         1.0
# 212         7.0         2.0         7.0         NaN         NaN         1.0
# 215         7.0         2.0         7.0         NaN         NaN         1.0
# 217         7.0         2.0         7.0         NaN         NaN         1.0
# 218         7.0         2.0         7.0         NaN         NaN         1.0
# 219         7.0         2.0         7.0         NaN         NaN         1.0
# 220         7.0         2.0         7.0         NaN         NaN         1.0
# 221         7.0         2.0         7.0         NaN         NaN         1.0
# 223         7.0         2.0         7.0         NaN         NaN         1.0
# 226         7.0         2.0         7.0         NaN         NaN         1.0
# 227         7.0         2.0         7.0         NaN         NaN         1.0
# 229         7.0         2.0         7.0         NaN         NaN         1.0
# 230         7.0         2.0         7.0         NaN         NaN         1.0
# 490         3.0         4.0         4.0         2.0         NaN         NaN
# 491         3.0         4.0         4.0         2.0         NaN         NaN
#
#      x1951_1960  x1961_1970  x1971_1980  x1981_1990  x1991_2000  x2001_2010  \
# 41          1.0         1.0         NaN         NaN         NaN         NaN
# 42          1.0         1.0         NaN         NaN         NaN         NaN
# 43          1.0         1.0         NaN         NaN         NaN         NaN
# 44          1.0         1.0         NaN         NaN         NaN         NaN
# 45          1.0         1.0         NaN         NaN         NaN         NaN
# 46          1.0         1.0         NaN         NaN         NaN         NaN
# 47          1.0         1.0         NaN         NaN         NaN         NaN
# 48          1.0         1.0         NaN         NaN         NaN         NaN
# 49          1.0         1.0         NaN         NaN         NaN         NaN
# 50          1.0         1.0         NaN         NaN         NaN         NaN
# 51          1.0         1.0         NaN         NaN         NaN         NaN
# 52          1.0         1.0         NaN         NaN         NaN         NaN
# 205         3.0         2.0         1.0         2.0         NaN         NaN
# 208         3.0         2.0         1.0         2.0         NaN         NaN
# 211         3.0         2.0         1.0         2.0         NaN         NaN
# 212         3.0         2.0         1.0         2.0         NaN         NaN
# 215         3.0         2.0         1.0         2.0         NaN         NaN
# 217         3.0         2.0         1.0         2.0         NaN         NaN
# 218         3.0         2.0         1.0         2.0         NaN         NaN
# 219         3.0         2.0         1.0         2.0         NaN         NaN
# 220         3.0         2.0         1.0         2.0         NaN         NaN
# 221         3.0         2.0         1.0         2.0         NaN         NaN
# 223         3.0         2.0         1.0         2.0         NaN         NaN
# 226         3.0         2.0         1.0         2.0         NaN         NaN
# 227         3.0         2.0         1.0         2.0         NaN         NaN
# 229         3.0         2.0         1.0         2.0         NaN         NaN
# 230         3.0         2.0         1.0         2.0         NaN         NaN
# 490         1.0         1.0         NaN         NaN         NaN         NaN
# 491         1.0         1.0         NaN         NaN         NaN         NaN
#
#      x2011_2015
# 41          NaN
# 42          NaN
# 43          NaN
# 44          NaN
# 45          NaN
# 46          NaN
# 47          NaN
# 48          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 52          NaN
# 205         NaN
# 208         NaN
# 211         NaN
# 212         NaN
# 215         NaN
# 217         NaN
# 218         NaN
# 219         NaN
# 220         NaN
# 221         NaN
# 223         NaN
# 226         NaN
# 227         NaN
# 229         NaN
# 230         NaN
# 490         NaN
# 491         NaN

# %%
# Model them all as AB_B, as majortiy of buildings is somewhat in this category
# Wrong Assesment of buildings here 
# overlap.loc[overlap['ueberw_dek'] == 'gemischte Baualtersklasse', 'ENHANCED_ARCHETYPE'] = 'AB_B'

# %%
def get_year(year_range):
    # Convert NaN and float to string or handle them separately
    if pd.isna(year_range):
        return None  # Handle NaN values explicitly
    if not isinstance(year_range, str):
        year_range = str(year_range)  # Convert non-string to string

    # Now the original logic, slightly adjusted for clarity
    if '-' in year_range:
        start_year, end_year = year_range.split('-')
        average_year = (int(start_year) + int(end_year)) // 2
        return average_year
    elif year_range == "gemischte Baualtersklasse":  # Fixed the condition checks
        return 1918
    elif year_range == "bis 1900":
        return 1900
    elif year_range == "NaN":  # This check might be redundant now
        return None

    try:
        return int(year_range)  # Handles cases where the year is not a range but a single year
    except ValueError:
        # Handles any unexpected string that cannot be converted directly to int
        return None

overlap["YEAR"] = overlap.apply(lambda row: get_year(row['ueberw_dek']), axis=1)

# %%
# Assign 1ST_USE type 
def match_1st_use_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        print(year)
        return None 
    year_range = find__enhanced_year_range(bldg_type, average_year)
    if bldg_type in ENHANCED_ARCHETYPES and year_range in ENHANCED_ARCHETYPES[bldg_type]:
        return ENHANCED_ARCHETYPES[bldg_type][year_range]
    return None

# %%
# Assumptions
# For all residential building types, the MULTI_RES is assigned
# For office (NWG1), OFFICE is assigned
# For University (NWG2), UNIVERSITY is assigned
# For IWU Health and care buildings (NWG3), HEALTH is assigned
# For School (NWG4), SCHOOL is assigned
# For culture (NWG 5), MUSEUM is assigned
# For sports facilities (NWG 6), GYM is assigned
# For hotels, restaurants e.g. (NWG 7), HOTEL is assigned
# For all production, workshop buildings (NWG 8), INDUSTRIAL is assigned
# For all trade buildings (NWG 9), RETAIL is assigned
# For all technicals and uitlity buildings (NWG 10, ), INDUSTRIAL is assigned
# For all IWU Transport (NWG 11), PARKING is assigned
# For all generalized Service buldings (NWG G1), OFFICE is assigned
# For all generalized industrial (NWG G2) INDUSTRIAL is assigned

USE_DICT = {
    'SFH': "SINGLE_RES",
    'AB' : "MULTI_RES",
    'MFH': "MULTI_RES",
    'TH': "SINGLE_RES",
    "HR" : "MULTI_RES",
    'NWG_1' : "OFFICE",
    "NWG_2" : "UNIVERSITY",
    "NWG_3" : "HEALTH",
    "NWG_4" : "SCHOOL",
    "NWG_5" : "MUSEUM",
    "NWG_6" : "GYM",
    "NWG_7" : "HOTEL",
    "NWG_8" : "INDUSTRIAL",
    "NWG_9" : "RETAIL",
    "NWG_10" : "INDUSTRIAL",
    "NWG_11" : "PARKING",
    "NWG_G1" : "OFFICE",
    "NWG_G2" : "INDUSTRIAL",

   
}

# Sort the keys by length in descending order to match longer keys first
keys = sorted(USE_DICT.keys(), key=len, reverse=True)

# Create a regex pattern to match any of the keys at the start of the string
pattern = r'^(' + '|'.join(map(re.escape, keys)) + ')'

# Extract the key using the regex pattern and map to USE_DICT
overlap['1ST_USE'] = overlap['ENHANCED_ARCHETYPE'].str.extract(pattern)[0].map(USE_DICT)

# %%
buildings_assigned_standard = overlap[overlap["1ST_USE"].notnull()]["Name"].tolist()

# %%
overlap
# Out:
#       Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0    B1000        2.0          2        3.0          1        NaN      school
# 1    B1001        3.0          3        3.0          1        NaN     service
# 2    B1002        1.0          1        3.0          1        NaN         yes
# 3    B1003        1.0          1        3.0          1        NaN         yes
# 4    B1004        6.0          6        3.0          1        NaN  apartments
# ..     ...        ...        ...        ...        ...        ...         ...
# 784  B1786        1.0          1        3.0          1        NaN         yes
# 785  B1787        6.0          6        3.0          1        NaN  apartments
# 786  B1788        6.0          6        3.0          1        NaN  apartments
# 787  B1789        6.0          6        3.0          1        NaN  apartments
# 788  B1790        4.0          4        3.0          1        NaN      church
#
#           REFERENCE house_no               street  ... x2001_2010  x2011_2015  \
# 0    OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 1    OSM - as it is       10  Lise-Meitner-Straße  ...        2.0         NaN
# 2    OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 3    OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 4    OSM - as it is      NaN                  NaN  ...        NaN         NaN
# ..              ...      ...                  ...  ...        ...         ...
# 784  OSM - as it is    17-20          Tegeler Weg  ...        NaN         NaN
# 785  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 786  OSM - as it is       21    Mierendorffstraße  ...        NaN         NaN
# 787  OSM - as it is       23    Mierendorffstraße  ...        NaN         NaN
# 788  OSM - as it is        1      Mindener Straße  ...        NaN         NaN
#
#      ew2015   typ                                            typklar  \
# 0     479.0  13.0                          Neubau-Schule (nach 1945)
# 1       NaN  37.0                        Kleingartenanlage allgemein
# 2     243.0  10.0  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 3     243.0  10.0  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 4     476.0  10.0  Blockrandbebauung mit Großhöfen (1920er-1940er...
# ..      ...   ...                                                ...
# 784   214.0  41.0                             Sicherheit und Ordnung
# 785   744.0   2.0  Geschlossene Blockbebauung, Hinterhof (1870er-...
# 786   675.0   1.0  Dichte Blockbebauung, geschlossener Hinterhof ...
# 787   675.0   1.0  Dichte Blockbebauung, geschlossener Hinterhof ...
# 788   444.0   2.0  Geschlossene Blockbebauung, Hinterhof (1870er-...
#
#     overlap_area  ARCHETYPE     1ST_USE ENHANCED_ARCHETYPE    YEAR
# 0    2526.631853    NWG_4_A      SCHOOL            NWG_4_A  1905.0
# 1     547.822059   NWG_10_B  INDUSTRIAL           NWG_10_B  2005.0
# 2    2139.055172       AB_D   MULTI_RES               AB_D  1955.0
# 3     472.988086       AB_D   MULTI_RES               AB_D  1955.0
# 4    1151.849618       None   MULTI_RES              MFH_H  1985.0
# ..           ...        ...         ...                ...     ...
# 784  6358.958904       AB_C   MULTI_RES               AB_C  1925.0
# 785  1949.023162       AB_C   MULTI_RES               AB_C  1925.0
# 786   764.306084       AB_B   MULTI_RES               AB_B  1905.0
# 787   696.337439       AB_B   MULTI_RES               AB_B  1905.0
# 788   911.996273    NWG_5_A      MUSEUM            NWG_5_A  1905.0
#
# [791 rows x 57 columns]

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    config.project = os.path.join(project_folder, 'Baseline')
    config.scenario_name = f'{year}'
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'Benchmark', f'{year}') 
    path_to_baseline = os.path.join(project_folder, 'Baseline', f'{year}')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
    except WindowsError:
        pass

# %%
overlap_copy = overlap.copy()

# Ensure no duplicate 'Name' values in overlap
overlap_copy = overlap_copy.drop_duplicates(subset='Name')

# Create a dictionary from overlap for fast lookup
overlap_dict = overlap_copy.set_index('Name').to_dict(orient='index')


# Custom function to update the STANDARD, 1ST_USE and YEAR columns
def update_columns(row):
    if row['Name'] in overlap_dict:
        arch = overlap_dict[row['Name']]['ARCHETYPE']
        enh_arch = overlap_dict[row['Name']]['ENHANCED_ARCHETYPE']
        first_use = overlap_dict[row['Name']]['1ST_USE']
        year = overlap_dict[row['Name']]['YEAR']
        
        standard = arch if pd.notna(arch) else enh_arch
        return pd.Series([standard, first_use])
    return pd.Series([row['STANDARD'], row['1ST_USE'], row["YEAR"]])

# %%
# Reset Index of overlap for mapping 
overlap["ARCHETYPE"] = np.where(overlap["ARCHETYPE"].isnull(), overlap["ENHANCED_ARCHETYPE"], overlap["ARCHETYPE"])
archetype_map = overlap.set_index('Name')['ARCHETYPE']
year_map = overlap.set_index('Name')['YEAR']
first_use_map = overlap.set_index('Name')['1ST_USE']

# %% [markdown]
# ## Benchmark Simulation

# %%
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]
# Check if output exsists, if so continue in loop
for year in years: 

    config.project = os.path.join(project_folder, 'Benchmark')
    config.scenario_name = f'{year}'
    config.general.database_path = "DE"
    config.save()
    path_to_new_scenario = os.path.join(project_folder, 'Benchmark', f'{year}')
    if os.path.exists(os.path.join(path_to_new_scenario, "outputs", "data", "demand", "Total_demand.csv")):
        continue

    
    archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
    archetype_file = gpd.read_file(archetype_path)

    archetype_file [['STANDARD', '1ST_USE', "YEAR"]] = archetype_file.apply(update_columns, axis=1)

    no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()


    archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    archetype_file = archetype_file[archetype_file['Name'].isin(archetype_buildings)]
    archetype_file.to_file(archetype_path)
    zone_path = os.path.join(path_to_new_scenario, "inputs", "building-geometry", "zone.shp")
    zone_gdf = gpd.read_file(zone_path)
    #zone_gdf.drop(zone_gdf[zone_gdf['Name'].isin(no_archetype_buildings)], inplace=True)
    zone_gdf = zone_gdf[zone_gdf['Name'].isin(archetype_buildings)]
    zone_gdf.to_file(zone_path)
    
    archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
                      buildings=archetype_buildings)
    config.schedule_maker.buildings = archetype_buildings 
    schedule_maker(config)
    #config.radiation.buildings = list_assigned_standard
    config.radiation.buildings = archetype_buildings
    radiation_main(config)   
    #config.demand.buildings = list_assigned_standard
    config.demand.overheating_warning = False
    demand_main(config)
# Out:
# Running occupancy model for scenario c:\Users\felix\Programmieren\Mierendorff_CEA\CEA_model337_12\Benchmark\2020
# Running occupancy model  with schedule model=deterministic
# Using 47 CPU's
# Schedule for building No. 1 completed out of 646: B1090
# Schedule for building No. 2 completed out of 646: B1000
# Schedule for building No. 3 completed out of 646: B1054
# Schedule for building No. 4 completed out of 646: B1004
# Schedule for building No. 5 completed out of 646: B1070
# Schedule for building No. 6 completed out of 646: B1032
# Schedule for building No. 7 completed out of 646: B1082
# Schedule for building No. 8 completed out of 646: B1074
# Schedule for building No. 9 completed out of 646: B1024
# Schedule for building No. 10 completed out of 646: B1008Schedule for building No. 11 completed out of 646: B1110
# Generating geometry for building 626 completed out of 646
# Generating geometry for building 627 completed out of 646
# Generating geometry for building 628 completed out of 646
# Generating geometry for building 629 completed out of 646
# Generating geometry for building 630 completed out of 646
# Generating geometry for building 631 completed out of 646
# Generating geometry for building 632 completed out of 646
# Generating geometry for building 633 completed out of 646
# Generating geometry for building 634 completed out of 646
# Generating geometry for building 635 completed out of 646
# Generating geometry for building 636 completed out of 646
# Generating geometry for building 637 completed out of 646
# Generating geometry for building 638 completed out of 646
# Generating geometry for building 639 completed out of 646
# Generating geometry for building 640 completed out of 646
# Generating geometry for building 641 completed out of 646
# Generating geometry for building 642 completed out of 646
# Generating geometry for building 643 completed out of 646
# Generating geometry for building 644 completed out of 646
# Generating geometry for building 645 completed out of 646
# Generating geometry for building 646 completed out of 646
# Creating radiance material file
# Creating radiance geometry file
# Converting files for DAYSIM
# Transforming weather files to daysim format
# Running command `epw2wea "c:\Users\felix\Programmieren\Mierendorff_CEA\CEA_model337_12\Benchmark\2020\inputs\weather\weather.epw" "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\common_inputs\weather_60min.wea"`
# place Berlin_ Germany
# latitude 52.510
# longitude -13.38
# time_zone -15.00
# site_elevation 44.9
# weather_data_file_units 1
#
# Transforming radiance files to daysim format
# Running command `radfiles2daysim "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\common_inputs\rad2daysim.hea" -g -m -d`
#
# Using 47 CPU's
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_0\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_6\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_4\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_5\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_3\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_2\
# Calculating and sending sensor points
# Creating daysim project in: C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_1\
# Calculating and sending sensor points
# Starting Daysim simulation for buildings: ['B1508', 'B1509', 'B1510', 'B1511', 'B1512', 'B1513', 'B1514', 'B1515', 'B1519', 'B1528', 'B1529', 'B1530', 'B1531', 'B1532', 'B1533', 'B1534', 'B1536', 'B1537', 'B1538', 'B1539', 'B1540', 'B1541', 'B1542', 'B1544', 'B1545', 'B1546', 'B1547', 'B1548', 'B1549', 'B1550', 'B1551', 'B1552', 'B1553', 'B1554', 'B1555', 'B1556', 'B1559', 'B1560', 'B1561', 'B1562', 'B1563', 'B1564', 'B1565', 'B1566', 'B1567', 'B1568', 'B1569', 'B1570', 'B1571', 'B1572', 'B1573', 'B1574', 'B1575', 'B1576', 'B1577', 'B1578', 'B1579', 'B1580', 'B1581', 'B1582', 'B1583', 'B1584', 'B1585', 'B1586', 'B1587', 'B1588', 'B1589', 'B1590', 'B1591', 'B1592', 'B1594', 'B1595', 'B1596', 'B1597', 'B1598', 'B1599', 'B1600', 'B1601', 'B1602', 'B1603', 'B1604', 'B1605', 'B1606', 'B1607', 'B1608', 'B1609', 'B1610', 'B1611', 'B1612', 'B1613', 'B1614', 'B1615', 'B1616', 'B1617', 'B1618', 'B1619', 'B1620', 'B1621', 'B1622', 'B1623']
# Total number of sensors: 4026
# Writing radiance parameters
# Executing hourly solar isolation calculation
# Running command `gen_dc "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk
:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_6\chunk_6.hea" -paste`
#
# Running command `ds_illum "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_6\chunk_6.hea"`
# Fixing inconsistencies, if any
# Removing leap day
# Writing results to disk
#
# Reading results...
# Fixing inconsistencies, if any
# Removing leap day
# Writing results to disk
#
# Reading results...
# =======================================================
# = gen_dc: calculate direct daylight coefficients      =
# = (this simulation may take several minutes to hours) =
# =======================================================
# calculate 63 direct daylight coefficients for variant static_system...
#
# Running command `gen_dc "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_2\chunk_2.hea" -dif`
# =======================================================
# = gen_dc: calculate direct daylight coefficients      =
# = (this simulation may take several minutes to hours) =
# =======================================================
# calculate 63 direct daylight coefficients for variant static_system...
#
# Running command `gen_dc "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_3\chunk_3.hea" -dif`
# Fixing inconsistencies, if any
# Removing leap day
# Writing results to disk
# =======================================================
# = gen_dc: calculate diffuse daylight coefficients     =
# = (ignore WARNING: no light sources found)            =
# = (this simulation may take several minutes to hours) =
# =======================================================
# calculate diffuse daylight coefficients for variant static_system...
#
# Running command `gen_dc "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_2\chunk_2.hea" -paste`
#
# Running command `ds_illum "C:\Users\felix\AppData\Local\Temp\tmp_fvxbmi8\cea_radiation\projects\chunk_2\chunk_2.hea"`

# %%
# Based on these findings, try to find a model that fits the data
# However, there is unvertainty in the data in the Renovation status of the buildings 
# Calibratin the year and renovation status is compute demanding task. 
# Troy to reduce the buildings as much as possible

# Shapes considered 
path_to__benchmark_shapes = os.path.join(project_folder, 'Benchmark', '2020', "inputs", "building-geometry", "zone.shp")	
benchmark_shapes_gdf = gpd.read_file(path_to__benchmark_shapes)
benchmark_shapes_gdf.plot()
# Out:
# <Axes: >

# %%
# There is a lack of builidngs and buildings below <100 sqm are still present
# Remove buildings below 100 sqm
# Validate the type and archetype for other buildings
# Figure out, why there is an ehnanced archetype for some buildings where no predomiant residential building age is present
no_archetype = overlap[overlap["ENHANCED_ARCHETYPE"].isnull()].Name.tolist()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 5
#       1 # There is a lack of builidngs and buildings below <100 sqm are still present
#       2 # Remove buildings below 100 sqm
#       3 # Validate the type and archetype for other buildings
#       4 # Figure out, why there is an ehnanced archetype for some buildings where no predomiant residential building age is present
# ----> 5 no_archetype = overlap[overlap["ENHANCED_ARCHETYPE"].isnull()].Name.tolist()
#
# NameError: name 'overlap' is not defined

# %%
# Get original shape file
path_to__baseline_shapes = os.path.join(project_folder, "Baseline", "2020", "inputs", "building-geometry", "zone.shp")
baseline_shapes_gdf = gpd.read_file(path_to__baseline_shapes)
baseline_shapes_gdf.plot()

# %%
baseline_shapes_gdf[baseline_shapes_gdf["Name"].isin(no_archetype)].plot()

# %% [markdown]
# # Retrofit

# %%
# Calibration
# Stop running schedule 
# Rerund radiation and archetypes
# Drop all data that is not needed

# %%
ARCHETYPES = {
    "No_Refurbishment" : "",
    "Normal_Refurbishment" : "_NR",
    "Advanced_Refurbishment" : "_AR"
}

# Write a function, that generates archetypes based on the building type and year

def create_renovation_status(refurbishment, bldg_type):
    # This function matches building use to its archetype based on year
    temp_standard = bldg_type.split("_")[0]
    if bldg_type.split("_")[-1] in ["NR", "AR"]:
        return bldg_type
    if temp_standard in ["SFH", "AB", "MFH", "HR", "TH"]:
        return bldg_type + ARCHETYPES[refurbishment]
    else:
        return bldg_type

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]
# Now generate a model, where everythin is modeled at as least one building type 
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for archetype in ARCHETYPES.keys():
    if archetype == "No_Refurbishment":
        continue
    

    for year in years: 
        config.project = os.path.join(project_folder, f'Benchmark_{archetype}')
        # create the destination path for copying the baseline scenario
        path_to_benchmark = os.path.join(project_folder, 'Benchmark', f'{year}') 
        path_to_new_scenario = os.path.join(project_folder, f'Benchmark_{archetype}', f'{year}')
        config.scenario_name = f'{year}'
        try:
            shutil.copytree(path_to_benchmark, path_to_new_scenario)
        except WindowsError:
            pass 


for archetype in ARCHETYPES.keys():
    if archetype == "No_Refurbishment":
        continue
    for year in years:
        config.project = os.path.join(project_folder, f'Benchmark_{archetype}')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE"
        config.save()
        path_to_new_scenario = os.path.join(project_folder, f'Benchmark_{archetype}', f'{year}')
        if os.path.exists(os.path.join(path_to_new_scenario, "outputs", "data", "demand", "Total_demand.csv")):
            continue
        archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
        archetype_file = gpd.read_file(archetype_path)

        archetype_file["STANDARD"] = archetype_file["STANDARD"].apply(lambda x: create_renovation_status(archetype, x))
        archetype_file.to_file(archetype_path)

        no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()
         
        archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    
    
        archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
                      buildings=archetype_buildings)
        archetypes_mapper_main(config)
        config.schedule_maker.buildings = archetype_buildings
        config.radiation.buildings = archetype_buildings
        config.radiation.consider_intersections = True
        config.schedule_maker.buildings = archetype_buildings 
        schedule_maker(config)
        radiation_main(config)   
        config.demand.buildings = archetype_buildings
        config.demand.overheating_warning = False
        demand_main(config)

# %% [markdown]
# # Stochastic

# %%
# Test stochastic CEA

# Test new german database

import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
    path_to_new_scenario = os.path.join(project_folder, 'Stochastic', f'{year}') # create the destination path for copying the baseline scenario
    path_to_benchmark= os.path.join(project_folder, 'Benchmark', year)
    try:
        shutil.copytree(path_to_benchmark, path_to_new_scenario)
    except WindowsError:
        pass 
    config.project = os.path.join(project_folder, 'Stochastic')
    config.scenario_name = f'{year}'
    path_to_new_scenario = os.path.join(project_folder, 'Stochastic', f'{year}')
    config.general.database_path = "DE"
    config.save()

# %%
import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
        path_to_new_scenario = os.path.join(project_folder, 'Stochastic', f'{year}')
        config.project = os.path.join(project_folder, 'Stochastic')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE"
        if os.path.exists(os.path.join(path_to_new_scenario, "outputs", "data", "demand", "Total_demand.csv")):
                continue
        archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
        archetype_file = gpd.read_file(archetype_path)


        no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()
         
        archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    
    
        archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
                      buildings=archetype_buildings)


        archetypes_mapper_main(config)
        config.schedule_maker.buildings = archetype_buildings 
        config.schedule_maker.schedule_model = "stochastic"
        schedule_maker(config)
        config.radiation.buildings = archetype_buildings
        config.radiation.consider_intersections = True
        radiation_main(config)   
        config.demand.buildings = archetype_buildings
        config.demand.overheating_warning = False
        demand_main(config)

# %% [markdown]
# # Fixed German Database

# %%
# Test new german database

import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
    path_to_new_scenario = os.path.join(project_folder, 'DE_FIX', f'{year}') # create the destination path for copying the baseline scenario
    path_to_benchmark= os.path.join(project_folder, 'Benchmark', year)
    try:
        shutil.copytree(path_to_benchmark, path_to_new_scenario)
    except WindowsError:
        pass 
    config.project = os.path.join(project_folder, 'DE_FIX')
    config.scenario_name = f'{year}'
    path_to_new_scenario = os.path.join(project_folder, 'DE_FIX', f'{year}')
    config.general.database_path = "DE_fix"
    config.save()
    #config.data_initializer(locator=cea.inputlocator.InputLocator(config.scenario), databases_path=r"C:\Users\felix\Documents\CityEnergyAnalyst\CityEnergyAnalyst\cea\databases\DE_updated")

# %%
import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
        path_to_new_scenario = os.path.join(project_folder, 'DE_FIX', f'{year}')
        config.project = os.path.join(project_folder, 'DE_FIX')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE_fix"
        if os.path.exists(os.path.join(path_to_new_scenario, "outputs", "data", "demand", "Total_demand.csv")):
                continue
        archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
        archetype_file = gpd.read_file(archetype_path)


        no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()
         
        archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    
    
        archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
                      buildings=archetype_buildings)


        archetypes_mapper_main(config)
        config.schedule_maker.buildings = archetype_buildings
        config.radiation.buildings = archetype_buildings
        config.radiation.consider_intersections = True
        config.schedule_maker.buildings = archetype_buildings 
        schedule_maker(config)
        radiation_main(config)   
        config.demand.buildings = archetype_buildings
        config.demand.overheating_warning = False
        demand_main(config)

# %% [markdown]
# # Updated German Database

# %%
# Test new german database

import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
    path_to_new_scenario = os.path.join(project_folder, 'Updated_DE_Database', f'{year}') # create the destination path for copying the baseline scenario
    path_to_benchmark= os.path.join(project_folder, 'Benchmark', year)
    try:
        shutil.copytree(path_to_benchmark, path_to_new_scenario)
    except WindowsError:
        pass 
    config.project = os.path.join(project_folder, 'Updated_DE_Database')
    config.scenario_name = f'{year}'
    path_to_new_scenario = os.path.join(project_folder, 'Updated_DE_Database', f'{year}')
    config.general.database_path = "DE_updated"
    config.save()
    #config.data_initializer(locator=cea.inputlocator.InputLocator(config.scenario), databases_path=r"C:\Users\felix\Documents\CityEnergyAnalyst\CityEnergyAnalyst\cea\databases\DE_updated")

# %%
import cea.config
from cea.datamanagement import data_initializer  
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years:
        path_to_new_scenario = os.path.join(project_folder, 'Updated_DE_Database', f'{year}')
        config.project = os.path.join(project_folder, 'Updated_DE_Database')
        config.scenario_name = f'{year}'
        config.general.database_path = "DE_updated"
        archetype_path = os.path.join(path_to_new_scenario, "inputs", "building-properties", "typology.dbf")
        archetype_file = gpd.read_file(archetype_path)


        no_archetype_buildings = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist() + archetype_file[archetype_file["1ST_USE"].isnull()]["Name"].tolist()
         
        archetype_buildings = [x for x in list(archetype_file["Name"]) if x not in no_archetype_buildings]
    
    
        archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=True, update_air_conditioning_systems_dbf=True, 
                      update_indoor_comfort_dbf=True, update_internal_loads_dbf=True, 
                      update_supply_systems_dbf=True, update_schedule_operation_cea=True, 
                      buildings=archetype_buildings)


        archetypes_mapper_main(config)
        config.schedule_maker.buildings = archetype_buildings
        config.radiation.buildings = archetype_buildings
        config.radiation.consider_intersections = True
        config.schedule_maker.buildings = archetype_buildings 
        schedule_maker(config)
        radiation_main(config)   
        config.demand.buildings = archetype_buildings
        config.demand.overheating_warning = False
        demand_main(config)

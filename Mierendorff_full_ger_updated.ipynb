# %%
# Import packages
import datetime
import geopandas as gpd
import holidays
# import july
import numpy as np
import os
import pandas as pd
from matplotlib import pyplot as plt
from dbfread import DBF
# import seaborn as sns
import shutil
import time
# Import CEA modules
import cea.config
import cea.api 
from cea.utilities.dbf import *
from cea.utilities.epwreader import epw_reader
from cea.datamanagement.archetypes_mapper import archetypes_mapper
from cea.demand.schedule_maker.schedule_maker import main as schedule_maker
from cea.demand.demand_main import main as demand_main
from cea.resources.radiation.main import main as radiation_main

#Take default dependencies for DAYSIM
# DAYSIM_BIN_DIRECTORY = os.path.join(os.getcwd(), 'CEA_model', '0_daysim_binaries')
project_folder = os.path.join(os.getcwd(), 'CEA_model')


zone_gdf = gpd.read_file(
    os.path.join(project_folder, 'Mierendorff_full', '2020_GER_updated', 'inputs', 'building-geometry', 'zone.shp')) 
list_buildings = zone_gdf["Name"].tolist() 

selection_gdf = zone_gdf.copy()
selection_gdf
# Out:
#       Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0    B1000          2          2          3          1        NaN      school
# 1    B1001          3          3          3          1        NaN     service
# 2    B1002          1          1          3          1        NaN         yes
# 3    B1003          1          1          3          1        NaN         yes
# 4    B1004          6          6          3          1        NaN  apartments
# ..     ...        ...        ...        ...        ...        ...         ...
# 785  B1785          1          1          3          1        NaN         yes
# 786  B1786          6          6          3          1        NaN  apartments
# 787  B1787          6          6          3          1        NaN  apartments
# 788  B1788          6          6          3          1        NaN  apartments
# 789  B1789          4          4          3          1        NaN      church
#
#           REFERENCE house_no               street postcode  house_name  \
# 0    OSM - as it is      NaN                  NaN      NaN         NaN
# 1    OSM - as it is       10  Lise-Meitner-Straße    10589         NaN
# 2    OSM - as it is      NaN                  NaN      NaN         NaN
# 3    OSM - as it is      NaN                  NaN      NaN         NaN
# 4    OSM - as it is      NaN                  NaN      NaN         NaN
# ..              ...      ...                  ...      ...         ...
# 785  OSM - as it is    17-20          Tegeler Weg    10589         NaN
# 786  OSM - as it is      NaN                  NaN      NaN         NaN
# 787  OSM - as it is       21    Mierendorffstraße    10589         NaN
# 788  OSM - as it is       23    Mierendorffstraße    10589         NaN
# 789  OSM - as it is        1      Mindener Straße    10589         NaN
#
#      resi_type    city country  \
# 0          NaN     NaN     NaN
# 1          NaN  Berlin      DE
# 2          NaN     NaN     NaN
# 3          NaN     NaN     NaN
# 4          NaN     NaN     NaN
# ..         ...     ...     ...
# 785        NaN  Berlin      DE
# 786        NaN     NaN     NaN
# 787        NaN  Berlin      DE
# 788        NaN  Berlin      DE
# 789        NaN  Berlin     NaN
#
#                                               geometry
# 0    POLYGON ((384886.006 5820581.206, 384886.119 5...
# 1    POLYGON ((385147.715 5821181.978, 385145.006 5...
# 2    POLYGON ((385315.603 5820595.263, 385265.770 5...
# 3    POLYGON ((385231.453 5820685.213, 385230.993 5...
# 4    POLYGON ((385092.809 5820650.440, 385096.097 5...
# ..                                                 ...
# 785  POLYGON ((384583.564 5821007.335, 384573.938 5...
# 786  POLYGON ((384534.446 5821185.198, 384551.996 5...
# 787  POLYGON ((384788.185 5820672.254, 384786.705 5...
# 788  POLYGON ((384799.372 5820694.503, 384795.628 5...
# 789  POLYGON ((384881.730 5820746.671, 384857.583 5...
#
# [790 rows x 16 columns]

# %%
# drop everything that is smaller than 40m2  
selection_gdf["area"] = selection_gdf["geometry"].area
buildings_above_40sqm = selection_gdf.query('area> 40')["Name"]

# %%
# adjust type on main type for block 
# first check if there is an overlap 
import os 
dir_path = os.getcwd()
shape_data_path = os.path.join(dir_path, 'auxillary',  '00_block_shape.shp')
shapes = gpd.read_file(shape_data_path)
shapes["blknr"] = shapes["blknr"].astype('int64') 
file_path_age = os.path.join(dir_path, 'auxillary','02_Gebäudealter.csv') 
age_df = pd.read_csv(file_path_age)
bldg_age_shapes =  shapes.merge(age_df, on='blknr')

# %%
zone_gdf["geometry"].intersects(bldg_age_shapes["geometry"], align=True)
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 785    False
# 786    False
# 787    False
# 788    False
# 789    False
# Length: 790, dtype: bool

# %%
list(zone_gdf["category"].value_counts().index)
# Out:
# ['yes',
#  'apartments',
#  'residential',
#  'industrial',
#  'commercial',
#  'allotment_house',
#  'roof',
#  'office',
#  'silo',
#  'retail',
#  'hut',
#  'school',
#  'public',
#  'service',
#  'warehouse',
#  'garages',
#  'church',
#  'house',
#  'garage',
#  'construction',
#  'manufacture',
#  'electricity',
#  'kindergarten',
#  'toilets',
#  'sports_hall',
#  'detached',
#  'houseboat']

# %% [markdown]
# # Archetye mapping
#
# Drop houseboat, detached, shed, train_station, toilets, bridge, construction, garage (s), hut, allotment_house, bungalow, church (?), roof, silo, electricity
#
# Assume yes is apparment.
#
# Compare with: https://wiki.openstreetmap.org/wiki/Key:building

# %%
bldg_to_drop = ["houseboat", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house",  "roof", "silo", "electricity"]

# %%
bldg_type_list = [x for x in list(zone_gdf["category"].value_counts().index) if x not in bldg_to_drop]
bldg_type_list
# Out:
# ['yes',
#  'apartments',
#  'residential',
#  'industrial',
#  'commercial',
#  'office',
#  'retail',
#  'school',
#  'public',
#  'service',
#  'warehouse',
#  'church',
#  'house',
#  'manufacture',
#  'kindergarten',
#  'sports_hall']

# %%
ARCHETYPES = {
     "apartments": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
    "residential": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
      "yes": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },
    "industrial": {
        "1860-1978": "NWG_G2_A",
        "1979-2009": "NWG_G2_B",
        "2010-2030": "NWG_G2_C",
    }, 

    "office": {
        "1860-1978": "NWG_1_A",
        "1979-2009": "NWG_1_B",
        "2010-2030": "NWG_1_C",
    },
      "commercial": {
        "1860-1978": "NWG_G1_A",
        "1979-2009": "NWG_G1_B",
        "2010-2030": "NWG_G1_C",
    }, 
    "retail" : {
        "1860-1978": "NWG_G1_A",
        "1979-2009": "NWG_G1_B",
        "2010-2030": "NWG_G1_C",
    }, 
    "warehouse": {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
        "service" : {
             "1860-1978": "NWG_10_A",
        "1979-2009": "NWG_10_B",
        "2010-2030": "NWG_10_C",
        },
        "school": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    },
    "public": {
           "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }, 
    "house": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },"manufacture" : {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
    
        "kindergarten": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    }, 
    "sports_hall": {
        "1860-1978": "NWG_6_A",
        "1979-2009": "NWG_6_B",
        "2010-2030": "NWG_6_C",
    }
    , 
    "church": {
        "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }}

# %%
print(ARCHETYPES.keys())
# Out:
# dict_keys(['apartments', 'residential', 'yes', 'industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public', 'house', 'manufacture', 'kindergarten', 'sports_hall', 'church'])

# %%
gpd.overlay(zone_gdf, bldg_age_shapes, how='intersection')
# Out:
#        Name  height_ag  floors_ag  height_bg  floors_bg descriptio  \
# 0     B1000          2          2          3          1        NaN
# 1     B1024          1          1          3          1        NaN
# 2     B1026          4          4          3          1        NaN
# 3     B1112          6          6          3          1        NaN
# 4     B1120          3          3          3          1        NaN
# ...     ...        ...        ...        ...        ...        ...
# 1385  B1778          6          6          3          1        NaN
# 1386  B1779          5          5          3          1        NaN
# 1387  B1780          6          6          3          1        NaN
# 1388  B1781          6          6          3          1        NaN
# 1389  B1782          5          5          3          1        NaN
#
#          category       REFERENCE house_no             street  ... x1961_1970  \
# 0          school  OSM - as it is      NaN                NaN  ...        NaN
# 1     sports_hall  OSM - as it is       29    Sömmeringstraße  ...        NaN
# 2          public  OSM - as it is       30  Mierendorffstraße  ...        NaN
# 3      apartments  OSM - as it is      NaN                NaN  ...        NaN
# 4             yes  OSM - as it is       22  Nordhauser Straße  ...        NaN
# ...           ...             ...      ...                ...  ...        ...
# 1385  residential  OSM - as it is      NaN                NaN  ...        NaN
# 1386   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1387   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1388   apartments  OSM - as it is      NaN                NaN  ...        NaN
# 1389   apartments  OSM - as it is      NaN                NaN  ...        NaN
#
#       x1971_1980  x1981_1990 x1991_2000 x2001_2010  x2011_2015 ew2015   typ  \
# 0            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 1            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 2            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 3            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# 4            1.0         1.0        NaN        NaN         NaN  479.0  13.0
# ...          ...         ...        ...        ...         ...    ...   ...
# 1385         NaN         NaN        NaN        NaN         NaN  300.0  10.0
# 1386         NaN         NaN        NaN        NaN         NaN  323.0  10.0
# 1387         NaN         NaN        NaN        NaN         NaN  691.0  10.0
# 1388         NaN         NaN        NaN        NaN         NaN  691.0  10.0
# 1389         NaN         NaN        NaN        NaN         NaN  336.0  10.0
#
#                                                 typklar  \
# 0                             Neubau-Schule (nach 1945)
# 1                             Neubau-Schule (nach 1945)
# 2                             Neubau-Schule (nach 1945)
# 3                             Neubau-Schule (nach 1945)
# 4                             Neubau-Schule (nach 1945)
# ...                                                 ...
# 1385  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1386  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1387  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1388  Blockrandbebauung mit Großhöfen (1920er-1940er...
# 1389  Blockrandbebauung mit Großhöfen (1920er-1940er...
#
#                                                geometry
# 0     POLYGON ((384886.119 5820587.190, 384891.934 5...
# 1     POLYGON ((385043.932 5820642.061, 385043.749 5...
# 2     POLYGON ((384922.724 5820735.592, 384929.001 5...
# 3     POLYGON ((385030.143 5820713.906, 385029.951 5...
# 4     POLYGON ((384966.057 5820720.330, 384966.311 5...
# ...                                                 ...
# 1385  POLYGON ((385451.043 5820715.937, 385446.869 5...
# 1386  POLYGON ((384649.990 5821130.060, 384649.766 5...
# 1387  POLYGON ((384620.571 5821059.758, 384631.713 5...
# 1388  POLYGON ((384622.619 5821008.006, 384622.870 5...
# 1389  POLYGON ((384665.434 5821218.355, 384669.302 5...
#
# [1390 rows x 52 columns]

# %%
def merge_with_max_overlap(gdf_buildings, gdf_blocks):
    # Initialize an empty list to store the result data
    results = []

    # Iterate over each polygon in gdf_buildings
    for index_a, row_a in gdf_buildings.iterrows():
        max_overlap = 0
        best_match = None

        # Compute intersection with each polygon in gdf_blocks and find the max overlap
        for index_b, row_b in gdf_blocks.iterrows():
            intersection = row_a['geometry'].intersection(row_b['geometry'])
            overlap_area = intersection.area

            if overlap_area > max_overlap:
                max_overlap = overlap_area
                best_match = row_b

        # Create a new record for the resulting GeoDataFrame
        if best_match is not None:
            merged_attrs = {**row_a.to_dict(), **best_match.to_dict(), 'overlap_area': max_overlap}
            results.append(merged_attrs)

    # Convert the list of dicts to a GeoDataFrame
    result_gdf = gpd.GeoDataFrame(results, crs=zone_gdf.crs)

    return result_gdf


overlap = merge_with_max_overlap(zone_gdf, bldg_age_shapes)

overlap.head()
# Out:
#     Name  height_ag  floors_ag  height_bg  floors_bg descriptio    category  \
# 0  B1000          2          2          3          1        NaN      school
# 1  B1001          3          3          3          1        NaN     service
# 2  B1002          1          1          3          1        NaN         yes
# 3  B1003          1          1          3          1        NaN         yes
# 4  B1004          6          6          3          1        NaN  apartments
#
#         REFERENCE house_no               street  ... x1961_1970  x1971_1980  \
# 0  OSM - as it is      NaN                  NaN  ...        NaN         1.0
# 1  OSM - as it is       10  Lise-Meitner-Straße  ...        NaN         NaN
# 2  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 3  OSM - as it is      NaN                  NaN  ...        NaN         NaN
# 4  OSM - as it is      NaN                  NaN  ...        NaN         1.0
#
#    x1981_1990 x1991_2000 x2001_2010 x2011_2015  ew2015   typ  \
# 0         1.0        NaN        NaN        NaN   479.0  13.0
# 1         NaN        NaN        2.0        NaN     NaN  37.0
# 2         NaN        NaN        NaN        NaN   243.0  10.0
# 3         NaN        NaN        NaN        NaN   243.0  10.0
# 4         5.0        NaN        NaN        NaN   476.0  10.0
#
#                                              typklar overlap_area
# 0                          Neubau-Schule (nach 1945)  2526.631853
# 1                        Kleingartenanlage allgemein   547.822059
# 2  Blockrandbebauung mit Großhöfen (1920er-1940er...  2139.055172
# 3  Blockrandbebauung mit Großhöfen (1920er-1940er...   472.988086
# 4  Blockrandbebauung mit Großhöfen (1920er-1940er...  1151.849618
#
# [5 rows x 53 columns]

# %%
# Add data for buildings ['B1325', 'B1769'] to the overlap file, then reorder by name 
selected_buildings = zone_gdf[zone_gdf["Name"].isin(['B1325', 'B1769'])]
overlap= gpd.GeoDataFrame(pd.concat([overlap, selected_buildings], ignore_index=True))

overlap = overlap.sort_values(by='Name')

# %%
gdf = zone_gdf
# Calculate bounds for consistent axis limits
xmin, ymin, xmax, ymax = gdf.total_bounds  # Get the bounding box of all geometries

# Extend the bounds a bit for better visualization
xrange = xmax - xmin
yrange = ymax - ymin
xmin -= 0.1 * xrange
xmax += 0.1 * xrange
ymin -= 0.1 * yrange
ymax += 0.1 * yrange

# Plot setup
fig, axs = plt.subplots(1, 4, figsize=(20, 8))  # Horizontal layout with 3 plots

# Plot all geometries
count_all = gdf.shape[0]
gdf.plot(ax=axs[0], color='blue', edgecolor='k')
axs[0].set_title(f'All Buildings obtained from OSM N = {count_all}')
axs[0].set_xlim(xmin, xmax)
axs[0].set_ylim(ymin, ymax)

# Plot residential builings
count_type_residential = gdf[gdf['category'].isin(["residential", "apartments", 'house, "bungalow", '])].shape[0]
gdf[gdf['category'].isin(["residential", "apartments", 'house'])].plot(ax=axs[1], color='green', edgecolor='k')
axs[1].set_title(f'Appartment and Residential Buildings N = {count_type_residential}')
axs[1].set_xlim(xmin, xmax)
axs[1].set_ylim(ymin, ymax)

# Plot non Residential Buildings
# Count type B entries
count_type_non_residential = gdf[gdf['category'].isin(['industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall', "church",])].shape[0]
gdf[gdf['category'].isin(['industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall'])].plot(ax=axs[2], color='red', edgecolor='k')
axs[2].set_title(f'Non-Residential Buildings N = {count_type_non_residential}')
axs[2].set_xlim(xmin, xmax)
axs[2].set_ylim(ymin, ymax)

# Plot non valid Building Types
count_type_invalid = gdf[gdf['category'].isin(["houseboat", "yes", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house", "roof", "silo", "electricity"])].shape[0]
gdf[gdf['category'].isin(["houseboat", "yes", "detached", "shed", "train_station", "toilets", "bridge", "construction", "garage", "garages", "hut", "allotment_house", "bungalow", "church", "roof", "silo", "electricity"])].plot(ax=axs[3], color='yellow', edgecolor='k')
axs[3].set_title(f'Invalid Building Types N = {count_type_invalid}')
axs[3].set_xlim(xmin, xmax)
axs[3].set_ylim(ymin, ymax)

# Remove the axis for a cleaner look and adjust for space between plots
for ax in axs:
    ax.axis('off')

# Common header
plt.suptitle('Visualization of Open Street Map Building Types', fontsize=16)

# Show plot
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the common header
plt.show()

# %%
def merge_with_max_overlap(gdf_buildings, gdf_blocks):
    # Initialize an empty list to store the result data
    results = []

    # Iterate over each polygon in gdf_buildings
    for index_a, row_a in gdf_buildings.iterrows():
        max_overlap = 0
        best_match = None
        best_match_attrs = None

        # Compute intersection with each polygon in gdf_blocks and find the max overlap
        for index_b, row_b in gdf_blocks.iterrows():
            intersection = row_a['geometry'].intersection(row_b['geometry'])
            overlap_area = intersection.area

            if overlap_area > max_overlap:
                max_overlap = overlap_area
                best_match = row_b
                # Exclude geometry from row_b to preserve the geometry from row_a
                best_match_attrs = {k: v for k, v in row_b.items() if k != 'geometry'}

        # Create a new record for the resulting GeoDataFrame, preserving row_a's geometry
        if best_match is not None:
            merged_attrs = {**row_a.to_dict(), **best_match_attrs, 'overlap_area': max_overlap}
            results.append(merged_attrs)

    # Convert the list of dicts to a GeoDataFrame
    result_gdf = gpd.GeoDataFrame(results, crs=gdf_buildings.crs)  # Ensure the CRS is taken from gdf_buildings

    return result_gdf

# Example usage:
# Assuming zone_gdf and bldg_age_shapes are your GeoDataFrames loaded beforehand
overlap_reduced = merge_with_max_overlap(zone_gdf, bldg_age_shapes)

# Print the first few rows of the resulting GeoDataFrame
overlap_reduced.head()

# %%
# Ingore yes here, due to diversity of building types
gdf = overlap[overlap['category'].isin(["residential", "apartments", 'house', "bungalow", ])]
# Calculate bounds for consistent axis limits
xmin, ymin, xmax, ymax = gdf.total_bounds  # Get the bounding box of all geometries

# Extend the bounds a bit for better visualization
xrange = xmax - xmin
yrange = ymax - ymin
xmin -= 0.1 * xrange
xmax += 0.1 * xrange
ymin -= 0.1 * yrange
ymax += 0.1 * yrange

# Plot setup
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # Horizontal layout with 3 plots

# Plot all geometries
gdf.plot(ax=axs[0], color='blue', edgecolor='k')
axs[0].set_title('All Buildings obtained from OSM')
axs[0].set_xlim(xmin, xmax)
axs[0].set_ylim(ymin, ymax)

# Plot types A and C
gdf[gdf['ueberw_dek'].isin(['2001-2010', '1901-1910', '1951-1960', '2011-2015', 'bis 1900', '1921-1930', '1981-1990', '1931-1940'])].plot(ax=axs[1], color='green', edgecolor='k')
axs[1].set_title('Predominant residential building age group given per block')
axs[1].set_xlim(xmin, xmax)
axs[1].set_ylim(ymin, ymax)

# Plot type B
gdf[gdf['ueberw_dek'].isin(["gemischte Baualtersklasse"])].plot(ax=axs[2], color='red', edgecolor='k')
axs[2].set_title('No predominant residential building age')
axs[2].set_xlim(xmin, xmax)
axs[2].set_ylim(ymin, ymax)

# Remove the axis for a cleaner look and adjust for space between plots
for ax in axs:
    ax.axis('off')

# Common header
plt.suptitle('Visualization of predominant building age groups', fontsize=16)

# Show plot
plt.tight_layout(rect=[0, 0, 1, 0.95])  # Adjust layout to make room for the common header
plt.show()

# %%
def average_year_from_range(year_range):
    # This function extracts the start and end years from a range, calculates the average, and returns it as an integer
    # "gemischte"
    if '-' in year_range:
        start_year, end_year = year_range.split('-')
        average_year = (int(start_year) + int(end_year)) // 2
        return average_year
    elif "year_range" == "gemischte Baualtersklasse":
        return None 
    elif "year_range" == "bis 1900": 
        return 1900
    elif "year_range" == "NaN":
        return None 

    return int(year_range)  # Handles cases where the year is not a range but a single year


def find_year_range(bldg_type, year):
    # function determines the year range that a given year falls into based on its categorization  
    if bldg_type in ["yes", "apartments", "residential", "house"]:
        #determine bldg age groups on years
        if 1860 <= year <= 1918:
            return "1860-1918"
        elif 1919 <= year <= 1948:
            return "1919-1948"
        elif 1949 <= year <= 1957:
            return "1949-1957"
        elif 1958 <= year <= 1968:
            return "1958-1968"
        elif 1969 <= year <= 1978:
            return "1969-1978"
        elif 1979 <= year <= 2009:
            return None
        else:
            return None 
    else:
        # Non Residential building groups
        if 1860 <= year <= 1978:
            return "1860-1978"
        elif 1979 <= year <= 2009:
            return "1979-2009"
        elif 2010 <= year <= 2030:
            return "2010-2030"
        else:
            return None



def match_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        print(year)
        return None 
    year_range = find_year_range(bldg_type, average_year)
    if bldg_type in ARCHETYPES and year_range in ARCHETYPES[bldg_type]:
        return ARCHETYPES[bldg_type][year_range]
    return None


overlap["ARCHETYPE"] = overlap.apply(lambda row: match_building_type(row['category'], row['ueberw_dek']), axis=1)
# Out:
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# bis 1900
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# bis 1900
# bis 1900
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# bis 1900
# nan
# nan
# nan
# nan
# nan
# gemischte Baualtersklasse
# gemischte Baualtersklasse
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
# Create folder for modelling based on suggestions 
archetype = "GER_Updated"
year = "2020"
path_to_new_scenario = os.path.join(project_folder, 'Mierendorff_full', f'{year}_{archetype}') # create the destination path for copying the baseline scenario
path_to_baseline = os.path.join(project_folder, 'Mierendorff_full', year)
try:
    shutil.copytree(path_to_baseline, path_to_new_scenario)
except WindowsError:
    pass

# %%
# map archetypes based on average year of block and building type 
archetype_path = os.path.join(project_folder, 'Mierendorff_full', f'{year}_{archetype}', "inputs", "building-properties", "typology.dbf")
archetype_file = gpd.read_file(archetype_path)
#archetype_file["STANDARD"] = archetype
archetype_file
# Out:
#       Name  STANDARD    YEAR    1ST_USE  1ST_USE_R 2ND_USE  2ND_USE_R 3RD_USE  \
# 0    B1000   NWG_4_A  1934.0     SCHOOL        1.0    NONE        0.0    NONE
# 1    B1001  NWG_10_B  1934.0    PARKING        1.0    NONE        0.0    NONE
# 2    B1002      AB_D  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 3    B1003      AB_D  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 4    B1004       NaN  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# ..     ...       ...     ...        ...        ...     ...        ...     ...
# 785  B1785      AB_B  1934.0     OFFICE        1.0    NONE        0.0    NONE
# 786  B1786      AB_B  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 787  B1787   NWG_5_A  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 788  B1788       NaN  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
# 789  B1789       NaN  1934.0  MULTI_RES        1.0    NONE        0.0    NONE
#
#      3RD_USE_R     REFERENCE geometry
# 0          0.0  OSM - median     None
# 1          0.0  OSM - median     None
# 2          0.0  OSM - median     None
# 3          0.0  OSM - median     None
# 4          0.0  OSM - median     None
# ..         ...           ...      ...
# 785        0.0  OSM - median     None
# 786        0.0  OSM - median     None
# 787        0.0  OSM - median     None
# 788        0.0  OSM - median     None
# 789        0.0  OSM - median     None
#
# [790 rows x 11 columns]

# %%
# Map the archetypes
archetype_file["STANDARD"] = overlap["ARCHETYPE"]

# %%
# Get the list of all builidngs that are modeled
# gdf['category'].isin(["residential", "apartments", 'house, "bungalow", '
'industrial', 'office', 'commercial', 'retail', 'warehouse', 'service', 'school', 'public',  'manufacture', 'kindergarten', 'sports_hall', "church", 
list_buildings = selection_gdf[(~selection_gdf["category"].isin(bldg_to_drop)) & (selection_gdf["area"] > 40)]["Name"].tolist()

# %%
len(list_buildings)
# Out:
# 597

# %%
# Get all Buildings, where an archetype was assigned
typology_dbf = gpd.read_file(r'CEA_model\Mierendorff_Full\2020_GER_Updated\inputs\building-properties\typology.dbf')

# %%
list_assigned_standard = typology_dbf[typology_dbf["STANDARD"].notnull()]["Name"].tolist()

# %%
list_assigned_standard
# Out:
# ['B1000',
#  'B1001',
#  'B1002',
#  'B1003',
#  'B1005',
#  'B1007',
#  'B1008',
#  'B1010',
#  'B1011',
#  'B1016',
#  'B1017',
#  'B1018',
#  'B1019',
#  'B1020',
#  'B1021',
#  'B1022',
#  'B1023',
#  'B1024',
#  'B1026',
#  'B1027',
#  'B1038',
#  'B1072',
#  'B1073',
#  'B1074',
#  'B1075',
#  'B1076',
#  'B1077',
#  'B1078',
#  'B1079',
#  'B1080',
#  'B1081',
#  'B1082',
#  'B1083',
#  'B1084',
#  'B1085',
#  'B1086',
#  'B1087',
#  'B1088',
#  'B1089',
#  'B1090',
#  'B1091',
#  'B1092',
#  'B1093',
#  'B1094',
#  'B1095',
#  'B1096',
#  'B1097',
#  'B1098',
#  'B1099',
#  'B1100',
#  'B1101',
#  'B1102',
#  'B1103',
#  'B1104',
#  'B1105',
#  'B1106',
#  'B1107',
#  'B1108',
#  'B1109',
#  'B1110',
#  'B1111',
#  'B1112',
#  'B1120',
#  'B1122',
#  'B1123',
#  'B1124',
#  'B1125',
#  'B1126',
#  'B1127',
#  'B1128',
#  'B1129',
#  'B1130',
#  'B1131',
#  'B1132',
#  'B1133',
#  'B1134',
#  'B1135',
#  'B1136',
#  'B1137',
#  'B1138',
#  'B1139',
#  'B1140',
#  'B1141',
#  'B1142',
#  'B1143',
#  'B1144',
#  'B1145',
#  'B1146',
#  'B1147',
#  'B1148',
#  'B1149',
#  'B1150',
#  'B1151',
#  'B1152',
#  'B1153',
#  'B1154',
#  'B1155',
#  'B1156',
#  'B1157',
#  'B1158',
#  'B1159',
#  'B1160',
#  'B1161',
#  'B1162',
#  'B1163',
#  'B1164',
#  'B1165',
#  'B1166',
#  'B1167',
#  'B1168',
#  'B1169',
#  'B1170',
#  'B1171',
#  'B1172',
#  'B1173',
#  'B1174',
#  'B1175',
#  'B1176',
#  'B1177',
#  'B1178',
#  'B1179',
#  'B1180',
#  'B1181',
#  'B1182',
#  'B1183',
#  'B1184',
#  'B1185',
#  'B1186',
#  'B1187',
#  'B1188',
#  'B1189',
#  'B1190',
#  'B1191',
#  'B1192',
#  'B1193',
#  'B1194',
#  'B1195',
#  'B1196',
#  'B1197',
#  'B1198',
#  'B1199',
#  'B1200',
#  'B1201',
#  'B1202',
#  'B1204',
#  'B1205',
#  'B1207',
#  'B1208',
#  'B1211',
#  'B1212',
#  'B1214',
#  'B1220',
#  'B1222',
#  'B1223',
#  'B1226',
#  'B1247',
#  'B1253',
#  'B1263',
#  'B1264',
#  'B1265',
#  'B1266',
#  'B1268',
#  'B1270',
#  'B1271',
#  'B1273',
#  'B1274',
#  'B1275',
#  'B1276',
#  'B1281',
#  'B1282',
#  'B1283',
#  'B1284',
#  'B1286',
#  'B1289',
#  'B1291',
#  'B1295',
#  'B1296',
#  'B1297',
#  'B1299',
#  'B1303',
#  'B1304',
#  'B1305',
#  'B1306',
#  'B1307',
#  'B1308',
#  'B1311',
#  'B1318',
#  'B1319',
#  'B1320',
#  'B1321',
#  'B1322',
#  'B1323',
#  'B1324',
#  'B1325',
#  'B1326',
#  'B1328',
#  'B1329',
#  'B1330',
#  'B1331',
#  'B1332',
#  'B1333',
#  'B1334',
#  'B1335',
#  'B1336',
#  'B1337',
#  'B1338',
#  'B1339',
#  'B1340',
#  'B1341',
#  'B1342',
#  'B1343',
#  'B1344',
#  'B1345',
#  'B1346',
#  'B1347',
#  'B1348',
#  'B1349',
#  'B1350',
#  'B1351',
#  'B1352',
#  'B1353',
#  'B1354',
#  'B1355',
#  'B1357',
#  'B1358',
#  'B1359',
#  'B1360',
#  'B1361',
#  'B1362',
#  'B1364',
#  'B1366',
#  'B1367',
#  'B1368',
#  'B1369',
#  'B1370',
#  'B1371',
#  'B1372',
#  'B1373',
#  'B1374',
#  'B1375',
#  'B1376',
#  'B1377',
#  'B1378',
#  'B1379',
#  'B1380',
#  'B1381',
#  'B1382',
#  'B1383',
#  'B1384',
#  'B1385',
#  'B1386',
#  'B1387',
#  'B1388',
#  'B1389',
#  'B1390',
#  'B1391',
#  'B1392',
#  'B1399',
#  'B1400',
#  'B1401',
#  'B1412',
#  'B1414',
#  'B1415',
#  'B1417',
#  'B1420',
#  'B1421',
#  'B1422',
#  'B1423',
#  'B1424',
#  'B1425',
#  'B1426',
#  'B1436',
#  'B1443',
#  'B1457',
#  'B1458',
#  'B1459',
#  'B1460',
#  'B1461',
#  'B1462',
#  'B1463',
#  'B1464',
#  'B1465',
#  'B1466',
#  'B1467',
#  'B1468',
#  'B1469',
#  'B1470',
#  'B1474',
#  'B1475',
#  'B1483',
#  'B1487',
#  'B1488',
#  'B1491',
#  'B1492',
#  'B1493',
#  'B1498',
#  'B1499',
#  'B1502',
#  'B1503',
#  'B1504',
#  'B1505',
#  'B1506',
#  'B1507',
#  'B1508',
#  'B1509',
#  'B1510',
#  'B1511',
#  'B1512',
#  'B1513',
#  'B1707',
#  'B1708',
#  'B1712',
#  'B1713',
#  'B1714',
#  'B1715',
#  'B1716',
#  'B1717',
#  'B1775',
#  'B1776',
#  'B1777',
#  'B1778',
#  'B1779',
#  'B1780',
#  'B1781',
#  'B1782',
#  'B1783',
#  'B1784',
#  'B1785',
#  'B1786',
#  'B1787']

# %%
# Build Baselines for all years
# Just consider the buildings that have been assigned a standard by simply mapping
# Name this default model
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    #config.data_helper.region = 'DE'
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'DefaultModel', f'{year}_GER_Updated') 
    path_to_baseline = os.path.join(project_folder, 'Mierendorff_full', f'{year}_GER_Updated')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
    except WindowsError:
        pass 
    # Set archetypes to previously identifed archetypes
    config.project = os.path.join(project_folder, 'DefaultModel')
    config.scenario_name = f'{year}_GER_Updated'
    
    archetype_path = os.path.join(project_folder, 'DefaultModel', f'{year}_GER_Updated', "inputs", "building-properties", "typology.dbf")
    archetype_file = gpd.read_file(archetype_path)
    archetype_file["STANDARD"] = overlap["ARCHETYPE"]
    archetype_file.to_file(archetype_path)
    zone_gdf = gpd.read_file(path_to_new_scenario + '/inputs/building-geometry/zone.shp')
    zone_gdf.drop(zone_gdf[~zone_gdf['Name'].isin(list_assigned_standard)].index, inplace=True)
    zone_gdf.to_file(path_to_new_scenario + '/inputs/building-geometry/zone.shp')


    #config.archetypes_mapper.buildings = list_assigned_standard
    config.schedule_maker.buildings = list_assigned_standard
    archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=False, update_air_conditioning_systems_dbf=False, 
                      update_indoor_comfort_dbf=False, update_internal_loads_dbf=False, 
                      update_supply_systems_dbf=False, update_schedule_operation_cea=True, 
                      buildings=list_assigned_standard)
    schedule_maker(config)
    #config.radiation.buildings = list_assigned_standard
    config.radiation.buildings = list_assigned_standard
    radiation_main(config)
    #config.demand.buildings = list_assigned_standard
    config.demand.overheating_warning = False
    demand_main(config)
# Out:
# Using Daysim binaries from path: c:\users\felix\documents\cityenergyanalyst\cityenergyanalyst\cea\resources\radiation\bin\win32\bin64
# Using Daysim data from path: c:\users\felix\documents\cityenergyanalyst\cityenergyanalyst\cea\resources\radiation\bin\win32\lib
# verifying geometry files
# zone: c:\Users\felix\Documents\Programmieren\Mierendorff_CEA\CEA_model\DefaultModel\2020_GER_Updated\inputs\building-geometry\zone.shp
# surroundings: c:\Users\felix\Documents\Programmieren\Mierendorff_CEA\CEA_model\DefaultModel\2020_GER_Updated\inputs\building-geometry\surroundings.shp
# trees: None
# Getting geometry materials
# Creating 3D geometry and surfaces
# Saving geometry pickle files in: c:\Users\felix\Documents\Programmieren\Mierendorff_CEA\CEA_model\DefaultModel\2020_GER_Updated\outputs\data\solar-radiation\radiance_geometry_pickle
# Standardizing coordinate systems
# Reprojected scene to `EPSG:32633`
# Reading terrain geometry
# Creating 3D building surfaces
# Calculating terrain intersection of building geometries
# Using 11 CPU's
# Calculation of terrain intersection for building 1 completed out of 330
# Calculation of terrain intersection for building 2 completed out of 330
# Calculation of terrain intersection for building 3 completed out of 330
# Calculation of terrain intersection for building 4 completed out of 330
# Calculation of terrain intersection for building 5 completed out of 330
# Calculation of terrain intersection for building 6 completed out of 330
# Calculation of terrain intersection for building 7 completed out of 330
# Calculation of terrain intersection for building 8 completed out of 330Calculation of terrain intersection for building 9 completed out of 330
#
# Calculation of terrain intersection for building 10 completed out of 330
# Calculation of terrain intersection for building 11 completed out of 330
# Calculation of terrain intersection for building 12 completed out of 330
# Calculation of terrain intersection for building 13 completed out of 330
# Calculation of terrain intersection for building 14 completed out of 330
# Calculation of terrain intersection for building 15 completed out of 330
# Calculation of terrain intersection for building 16 completed out of 330
# Calculation of terrain intersection for building 17 completed out of 330
# Calculation of terrain intersection for building 18 completed out of 330
# Calculation of terrain intersection for building 19 completed out of 330
# Calculation of terrain intersection for building 20 completed out of 330
# Calculation of terrain intersection for building 21 completed out of 330
# Calculation of terrain intersection for building 22 completed out of 330
# Calculation of terrain intersection for building 23 completed out of 330
# Calculation of terrain intersection for building 24 completed out of 330
# Calculation of terrain intersection for building 25 completed out of 330
# Calculation of terrain intersection for building 26 completed out of 330
# Calculation of terrain intersection for building 27 completed out of 330
# Calculation of terrain intersection for building 28 completed out of 330
# Calculation of terrain intersection for building 29 completed out of 330
# Calculation of terrain intersection for building 30 completed out of 330
# Calculation of terrain intersection for building 31 completed out of 330
# Calculation of terrain intersection for building 32 completed out of 330
# Calculation of terrain intersection for building 33 completed out of 330
# Calculation of terrain intersection for building 34 completed out of 330
# Calculation of terrain intersection for building 35 completed out of 330
# Calculation of terrain intersection for building 36 completed out of 330Calculation of terrain intersection for building 37 completed out of 330
#
# Calculation of terrain intersection for building 38 completed out of 330
# Calculation of terrain intersection for building 39 completed out of 330
# Calculation of terrain intersection for building 40 completed out of 330
# Calculation of terrain intersection for building 41 completed out of 330
# Calculation of terrain intersection for building 42 completed out of 330
# Calculation of terrain intersection for building 43 completed out of 330
# Calculation of terrain intersection for building 44 completed out of 330
# Calculation of terrain intersection for building 45 completed out of 330
# Calculation of terrain intersection for building 46 completed out of 330
# Calculation of terrain intersection for building 47 completed out of 330
# Calculation of terrain intersection for building 48 completed out of 330
# Calculation of terrain intersection for building 49 completed out of 330
# Calculation of terrain intersection for building 50 completed out of 330
# Calculation of terrain intersection for building 51 completed out of 330
# Calculation of terrain intersection for building 52 completed out of 330
# Calculation of terrain intersection for building 53 completed out of 330
# Calculation of terrain intersection for building 54 completed out of 330
# Calculation of terrain intersection for building 55 completed out of 330
# Calculation of terrain intersection for building 56 completed out of 330
# Calculation of terrain intersection for building 57 completed out of 330
# Calculation of terrain intersection for building 58 completed out of 330Calculation of terrain intersection for building 59 completed out of 330
#
# Calculation of terrain intersection for building 60 completed out of 330
# Calculation of terrain intersection for building 61 completed out of 330
# Calculation of terrain intersection for building 62 completed out of 330
# Calculation of terrain intersection for building 63 completed out of 330
# Calculation of terrain intersection for building 64 completed out of 330
# Calculation of terrain intersection for building 65 completed out of 330
# Calculation of terrain intersection for building 66 completed out of 330
# Calculation of terrain intersection for building 67 completed out of 330
# Calculation of terrain intersection for building 68 completed out of 330Calculation of terrain intersection for building 69 completed out of 330
#
# Calculation of terrain intersection for building 70 completed out of 330
# Calculation of terrain intersection for building 71 completed out of 330
# Calculation of terrain intersection for building 72 completed out of 330
# Calculation of terrain intersection for building 73 completed out of 330
# Calculation of terrain intersection for building 74 completed out of 330
# Calculation of terrain intersection for building 75 completed out of 330
# Calculation of terrain intersection for building 76 completed out of 330
# Calculation of terrain intersection for building 77 completed out of 330
# Calculation of terrain intersection for building 78 completed out of 330
# Calculation of terrain intersection for building 79 completed out of 330
# Calculation of terrain intersection for building 80 completed out of 330
# Calculation of terrain intersection for building 81 completed out of 330
# Calculation of terrain intersection for building 82 completed out of 330
# Calculation of terrain intersection for building 83 completed out of 330
# Calculation of terrain intersection for building 84 completed out of 330
# Calculation of terrain intersection for building 85 completed out of 330
# Calculation of terrain intersection for building 86 completed out of 330
# Calculation of terrain intersection for building 87 completed out of 330
# Calculation of terrain intersection for building 88 completed out of 330
# Calculation of terrain intersection for building 89 completed out of 330
# Calculation of terrain intersection for building 90 completed out of 330
# Calculation of terrain intersection for building 91 completed out of 330
# Calculation of terrain intersection for building 92 completed out of 330
# Calculation of terrain intersection for building 93 completed out of 330
# Calculation of terrain intersection for building 94 completed out of 330
# Calculation of terrain intersection for building 95 completed out of 330
# Calculation of terrain intersection for building 96 completed out of 330
# Calculation of terrain intersection for building 97 completed out of 330
# Calculation of terrain intersection for building 98 completed out of 330
# Calculation of terrain intersection for building 99 completed out of 330
# Calculation of terrain intersection for building 100 completed out of 330
# Calculation of terrain intersection for building 101 completed out of 330
# Calculation of terrain intersection for building 102 completed out of 330
# Calculation of terrain intersection for building 103 completed out of 330
# Calculation of terrain intersection for building 104 completed out of 330
# Calculation of terrain intersection for building 105 completed out of 330
# Calculation of terrain intersection for building 106 completed out of 330
# Calculation of terrain intersection for building 107 completed out of 330
# Calculation of terrain intersection for building 108 completed out of 330
# Calculation of terrain intersection for building 109 completed out of 330
# Calculation of terrain intersection for building 110 completed out of 330
# Calculation of terrain intersection for building 111 completed out of 330
# Calculation of terrain intersection for building 112 completed out of 330
# Calculation of terrain intersection for building 113 completed out of 330
# Calculation of terrain intersection for building 114 completed out of 330
# Calculation of terrain intersection for building 115 completed out of 330
# Calculation of terrain intersection for building 116 completed out of 330
# Calculation of terrain intersection for building 117 completed out of 330
# Calculation of terrain intersection for building 118 completed out of 330
# Calculation of terrain intersection for building 119 completed out of 330
# Calculation of terrain intersection for building 120 completed out of 330
# Calculation of terrain intersection for building 121 completed out of 330
# Calculation of terrain intersection for building 122 completed out of 330
# Calculation of terrain intersection for building 123 completed out of 330
# Calculation of terrain intersection for building 124 completed out of 330
# Calculation of terrain intersection for building 125 completed out of 330
# Calculation of terrain intersection for building 126 completed out of 330
# Calculation of terrain intersection for building 127 completed out of 330
# Calculation of terrain intersection for building 128 completed out of 330
# Calculation of terrain intersection for building 129 completed out of 330
# Calculation of terrain intersection for building 130 completed out of 330
# Calculation of terrain intersection for building 131 completed out of 330
# Calculation of terrain intersection for building 132 completed out of 330
# Calculation of terrain intersection for building 133 completed out of 330
# Calculation of terrain intersection for building 134 completed out of 330
# Calculation of terrain intersection for building 135 completed out of 330
# Calculation of terrain intersection for building 136 completed out of 330
# Calculation of terrain intersection for building 137 completed out of 330
# Calculation of terrain intersection for building 138 completed out of 330
# Calculation of terrain intersection for building 139 completed out of 330
# Calculation of terrain intersection for building 140 completed out of 330
# Calculation of terrain intersection for building 141 completed out of 330
# Calculation of terrain intersection for building 142 completed out of 330
# Calculation of terrain intersection for building 143 completed out of 330
# Calculation of terrain intersection for building 144 completed out of 330
# Calculation of terrain intersection for building 145 completed out of 330
# Calculation of terrain intersection for building 146 completed out of 330
# Calculation of terrain intersection for building 147 completed out of 330
# Calculation of terrain intersection for building 148 completed out of 330
# Calculation of terrain intersection for building 149 completed out of 330
# Calculation of terrain intersection for building 150 completed out of 330
# Calculation of terrain intersection for building 151 completed out of 330
# Calculation of terrain intersection for building 152 completed out of 330
# Calculation of terrain intersection for building 153 completed out of 330
# Calculation of terrain intersection for building 154 completed out of 330
# Calculation of terrain intersection for building 155 completed out of 330
# Calculation of terrain intersection for building 156 completed out of 330
# Calculation of terrain intersection for building 157 completed out of 330
# Calculation of terrain intersection for building 158 completed out of 330
# Calculation of terrain intersection for building 159 completed out of 330
# Calculation of terrain intersection for building 160 completed out of 330
# Calculation of terrain intersection for building 161 completed out of 330
# Calculation of terrain intersection for building 162 completed out of 330
# Calculation of terrain intersection for building 163 completed out of 330
# Calculation of terrain intersection for building 164 completed out of 330
# Calculation of terrain intersection for building 165 completed out of 330
# Calculation of terrain intersection for building 166 completed out of 330Calculation of terrain intersection for building 167 completed out of 330
#
# Calculation of terrain intersection for building 168 completed out of 330
# Calculation of terrain intersection for building 169 completed out of 330
# Calculation of terrain intersection for building 170 completed out of 330
# Calculation of terrain intersection for building 171 completed out of 330
# Calculation of terrain intersection for building 172 completed out of 330
# Calculation of terrain intersection for building 173 completed out of 330
# Calculation of terrain intersection for building 174 completed out of 330
# Calculation of terrain intersection for building 175 completed out of 330
# Calculation of terrain intersection for building 176 completed out of 330
# Calculation of terrain intersection for building 177 completed out of 330
# Calculation of terrain intersection for building 179 completed out of 330
# Calculation of terrain intersection for building 178 completed out of 330
# Calculation of terrain intersection for building 180 completed out of 330
# Calculation of terrain intersection for building 181 completed out of 330
# Calculation of terrain intersection for building 182 completed out of 330
# Calculation of terrain intersection for building 183 completed out of 330
# Calculation of terrain intersection for building 184 completed out of 330
# Calculation of terrain intersection for building 185 completed out of 330
# Calculation of terrain intersection for building 187 completed out of 330
# Calculation of terrain intersection for building 188 completed out of 330
# Calculation of terrain intersection for building 186 completed out of 330
# Calculation of terrain intersection for building 189 completed out of 330
# Calculation of terrain intersection for building 190 completed out of 330
# Calculation of terrain intersection for building 191 completed out of 330
# Calculation of terrain intersection for building 192 completed out of 330
# Calculation of terrain intersection for building 193 completed out of 330
# Calculation of terrain intersection for building 194 completed out of 330
# Calculation of terrain intersection for building 195 completed out of 330
# Calculation of terrain intersection for building 196 completed out of 330
# Calculation of terrain intersection for building 197 completed out of 330
# Calculation of terrain intersection for building 198 completed out of 330Calculation of terrain intersection for building 199 completed out of 330
#
# Calculation of terrain intersection for building 200 completed out of 330
# Calculation of terrain intersection for building 201 completed out of 330
# Calculation of terrain intersection for building 202 completed out of 330
# Calculation of terrain intersection for building 203 completed out of 330
# Calculation of terrain intersection for building 204 completed out of 330
# Calculation of terrain intersection for building 205 completed out of 330
# Calculation of terrain intersection for building 206 completed out of 330
# Calculation of terrain intersection for building 207 completed out of 330
# Calculation of terrain intersection for building 208 completed out of 330
# Calculation of terrain intersection for building 209 completed out of 330
# Calculation of terrain intersection for building 210 completed out of 330
# Calculation of terrain intersection for building 211 completed out of 330
# Calculation of terrain intersection for building 212 completed out of 330
# Calculation of terrain intersection for building 213 completed out of 330
# Calculation of terrain intersection for building 214 completed out of 330
# Calculation of terrain intersection for building 215 completed out of 330
# Calculation of terrain intersection for building 216 completed out of 330
# Calculation of terrain intersection for building 217 completed out of 330
# Calculation of terrain intersection for building 218 completed out of 330
# Calculation of terrain intersection for building 219 completed out of 330
# Calculation of terrain intersection for building 220 completed out of 330
# Calculation of terrain intersection for building 221 completed out of 330
# Calculation of terrain intersection for building 222 completed out of 330
# Calculation of terrain intersection for building 223 completed out of 330
# Calculation of terrain intersection for building 224 completed out of 330
# Calculation of terrain intersection for building 225 completed out of 330
# Calculation of terrain intersection for building 226 completed out of 330
# Calculation of terrain intersection for building 227 completed out of 330
# Calculation of terrain intersection for building 228 completed out of 330
# Calculation of terrain intersection for building 229 completed out of 330
# Calculation of terrain intersection for building 230 completed out of 330
# Calculation of terrain intersection for building 231 completed out of 330
# Calculation of terrain intersection for building 232 completed out of 330
# Calculation of terrain intersection for building 233 completed out of 330
# Calculation of terrain intersection for building 234 completed out of 330
# Calculation of terrain intersection for building 235 completed out of 330
# Calculation of terrain intersection for building 236 completed out of 330
# Calculation of terrain intersection for building 237 completed out of 330
# Calculation of terrain intersection for building 238 completed out of 330
# Calculation of terrain intersection for building 239 completed out of 330
# Calculation of terrain intersection for building 240 completed out of 330
# Calculation of terrain intersection for building 241 completed out of 330
# Calculation of terrain intersection for building 242 completed out of 330
# Calculation of terrain intersection for building 243 completed out of 330
# Calculation of terrain intersection for building 244 completed out of 330
# Calculation of terrain intersection for building 245 completed out of 330
# Calculation of terrain intersection for building 246 completed out of 330
# Calculation of terrain intersection for building 247 completed out of 330Calculation of terrain intersection for building 248 completed out of 330
#
# Calculation of terrain intersection for building 249 completed out of 330
# Calculation of terrain intersection for building 250 completed out of 330
# Calculation of terrain intersection for building 251 completed out of 330
# Calculation of terrain intersection for building 252 completed out of 330
# Calculation of terrain intersection for building 253 completed out of 330
# Calculation of terrain intersection for building 254 completed out of 330
# Calculation of terrain intersection for building 255 completed out of 330Calculation of terrain intersection for building 256 completed out of 330
#
# Calculation of terrain intersection for building 257 completed out of 330
# Calculation of terrain intersection for building 258 completed out of 330
# Calculation of terrain intersection for building 259 completed out of 330
# Calculation of terrain intersection for building 260 completed out of 330
# Calculation of terrain intersection for building 261 completed out of 330
# Calculation of terrain intersection for building 262 completed out of 330
# Calculation of terrain intersection for building 263 completed out of 330
# Calculation of terrain intersection for building 264 completed out of 330
# Calculation of terrain intersection for building 265 completed out of 330
# Calculation of terrain intersection for building 266 completed out of 330
# Calculation of terrain intersection for building 267 completed out of 330
# Calculation of terrain intersection for building 268 completed out of 330
# Calculation of terrain intersection for building 269 completed out of 330
# Calculation of terrain intersection for building 270 completed out of 330
# Calculation of terrain intersection for building 271 completed out of 330
# Calculation of terrain intersection for building 272 completed out of 330
# Calculation of terrain intersection for building 273 completed out of 330
# Calculation of terrain intersection for building 274 completed out of 330
# Calculation of terrain intersection for building 275 completed out of 330
# Calculation of terrain intersection for building 276 completed out of 330
# Calculation of terrain intersection for building 277 completed out of 330
# Calculation of terrain intersection for building 278 completed out of 330
# Calculation of terrain intersection for building 279 completed out of 330
# Calculation of terrain intersection for building 280 completed out of 330
# Calculation of terrain intersection for building 281 completed out of 330
# Calculation of terrain intersection for building 282 completed out of 330
# Calculation of terrain intersection for building 283 completed out of 330
# Calculation of terrain intersection for building 284 completed out of 330
# Calculation of terrain intersection for building 285 completed out of 330
# Calculation of terrain intersection for building 286 completed out of 330
# Calculation of terrain intersection for building 287 completed out of 330
# Calculation of terrain intersection for building 288 completed out of 330
# Calculation of terrain intersection for building 289 completed out of 330
# Calculation of terrain intersection for building 290 completed out of 330
# Calculation of terrain intersection for building 291 completed out of 330
# Calculation of terrain intersection for building 292 completed out of 330
# Calculation of terrain intersection for building 293 completed out of 330
# Calculation of terrain intersection for building 294 completed out of 330
# Calculation of terrain intersection for building 295 completed out of 330
# Calculation of terrain intersection for building 296 completed out of 330
# Calculation of terrain intersection for building 297 completed out of 330
# Calculation of terrain intersection for building 298 completed out of 330
# Calculation of terrain intersection for building 299 completed out of 330
# Calculation of terrain intersection for building 300 completed out of 330
# Calculation of terrain intersection for building 301 completed out of 330
# Calculation of terrain intersection for building 302 completed out of 330
# Calculation of terrain intersection for building 303 completed out of 330
# Calculation of terrain intersection for building 304 completed out of 330
# Calculation of terrain intersection for building 305 completed out of 330
# Calculation of terrain intersection for building 306 completed out of 330
# Calculation of terrain intersection for building 307 completed out of 330
# Calculation of terrain intersection for building 308 completed out of 330
# Calculation of terrain intersection for building 309 completed out of 330
# Calculation of terrain intersection for building 310 completed out of 330
# Calculation of terrain intersection for building 311 completed out of 330
# Calculation of terrain intersection for building 312 completed out of 330
# Calculation of terrain intersection for building 313 completed out of 330
# Calculation of terrain intersection for building 314 completed out of 330
# Calculation of terrain intersection for building 315 completed out of 330
# Calculation of terrain intersection for building 316 completed out of 330
# Calculation of terrain intersection for building 317 completed out of 330
# Calculation of terrain intersection for building 318 completed out of 330
# Calculation of terrain intersection for building 319 completed out of 330
# Calculation of terrain intersection for building 320 completed out of 330
# Calculation of terrain intersection for building 321 completed out of 330
# Calculation of terrain intersection for building 322 completed out of 330
# Calculation of terrain intersection for building 323 completed out of 330
# Calculation of terrain intersection for building 324 completed out of 330
# Calculation of terrain intersection for building 325 completed out of 330
# Calculation of terrain intersection for building 326 completed out of 330
# Calculation of terrain intersection for building 327 completed out of 330
# Calculation of terrain intersection for building 328 completed out of 330
# Calculation of terrain intersection for building 329 completed out of 330
# Calculation of terrain intersection for building 330 completed out of 330
# Using 11 CPU's
# Calculation of terrain intersection for building 1 completed out of 1
# Generating geometry for surrounding buildings
# Generating geometry for buildings in the zone of analysis
# Using 11 CPU's
# Generating geometry for building 1 completed out of 330
# Generating geometry for building 2 completed out of 330
# Generating geometry for building 3 completed out of 330
# Generating geometry for building 4 completed out of 330
# Generating geometry for building 5 completed out of 330
# Generating geometry for building 6 completed out of 330
# Generating geometry for building 7 completed out of 330
# Generating geometry for building 8 completed out of 330
# Generating geometry for building 9 completed out of 330
# Generating geometry for building 10 completed out of 330
# Generating geometry for building 11 completed out of 330
# Generating geometry for building 12 completed out of 330
# Generating geometry for building 13 completed out of 330
# Generating geometry for building 14 completed out of 330
# Generating geometry for building 15 completed out of 330
# Generating geometry for building 16 completed out of 330
# Generating geometry for building 17 completed out of 330
# Generating geometry for building 18 completed out of 330
# Generating geometry for building 19 completed out of 330
# Generating geometry for building 20 completed out of 330
# Generating geometry for building 21 completed out of 330
# Generating geometry for building 22 completed out of 330
# Generating geometry for building 23 completed out of 330
# Generating geometry for building 24 completed out of 330
# Generating geometry for building 25 completed out of 330
# Generating geometry for building 26 completed out of 330
# Generating geometry for building 27 completed out of 330
# Generating geometry for building 28 completed out of 330
# Generating geometry for building 29 completed out of 330
# Generating geometry for building 30 completed out of 330
# Generating geometry for building 31 completed out of 330
# Generating geometry for building 32 completed out of 330
# Generating geometry for building 33 completed out of 330
# Generating geometry for building 34 completed out of 330
# Generating geometry for building 35 completed out of 330
# Generating geometry for building 36 completed out of 330
# Generating geometry for building 37 completed out of 330
# Generating geometry for building 38 completed out of 330
# Generating geometry for building 39 completed out of 330
# Generating geometry for building 40 completed out of 330
# Generating geometry for building 41 completed out of 330
# Generating geometry for building 42 completed out of 330
# Generating geometry for building 43 completed out of 330
# Generating geometry for building 44 completed out of 330
# Generating geometry for building 45 completed out of 330
# Generating geometry for building 46 completed out of 330
# Generating geometry for building 47 completed out of 330
# Generating geometry for building 48 completed out of 330
# Generating geometry for building 49 completed out of 330
# Generating geometry for building 50 completed out of 330
# Generating geometry for building 51 completed out of 330
# Generating geometry for building 52 completed out of 330
# Generating geometry for building 53 completed out of 330
# Generating geometry for building 54 completed out of 330
# Generating geometry for building 55 completed out of 330
# Generating geometry for building 56 completed out of 330
# Generating geometry for building 57 completed out of 330
# Generating geometry for building 58 completed out of 330
# Generating geometry for building 59 completed out of 330
# Generating geometry for building 60 completed out of 330
# Generating geometry for building 61 completed out of 330
# Generating geometry for building 62 completed out of 330
# Generating geometry for building 63 completed out of 330
# Generating geometry for building 64 completed out of 330
# Generating geometry for building 65 completed out of 330
# Generating geometry for building 66 completed out of 330
# Generating geometry for building 67 completed out of 330
# Generating geometry for building 68 completed out of 330
# Generating geometry for building 69 completed out of 330
# Generating geometry for building 70 completed out of 330
# Generating geometry for building 71 completed out of 330
# Generating geometry for building 72 completed out of 330
# Generating geometry for building 73 completed out of 330
# Generating geometry for building 74 completed out of 330
# Generating geometry for building 75 completed out of 330
# Generating geometry for building 76 completed out of 330
# Generating geometry for building 77 completed out of 330
# Generating geometry for building 78 completed out of 330
# Generating geometry for building 79 completed out of 330
# Generating geometry for building 80 completed out of 330
# Generating geometry for building 81 completed out of 330
# Generating geometry for building 82 completed out of 330
# Generating geometry for building 83 completed out of 330
# Generating geometry for building 84 completed out of 330
# Generating geometry for building 85 completed out of 330
# Generating geometry for building 86 completed out of 330
# Generating geometry for building 87 completed out of 330
# Generating geometry for building 88 completed out of 330
# Generating geometry for building 89 completed out of 330
# Generating geometry for building 90 completed out of 330
# Generating geometry for building 91 completed out of 330
# Generating geometry for building 92 completed out of 330
# Generating geometry for building 93 completed out of 330
# Generating geometry for building 94 completed out of 330
# Generating geometry for building 95 completed out of 330
# Generating geometry for building 96 completed out of 330
# Generating geometry for building 97 completed out of 330
# Generating geometry for building 98 completed out of 330
# Generating geometry for building 99 completed out of 330
# Generating geometry for building 100 completed out of 330
# Generating geometry for building 101 completed out of 330
# Generating geometry for building 102 completed out of 330
# Generating geometry for building 103 completed out of 330
# Generating geometry for building 104 completed out of 330
# Generating geometry for building 105 completed out of 330
# Generating geometry for building 106 completed out of 330

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    config.project = os.path.join(project_folder, 'DefaultModel')
    config.scenario_name = f'{year}_GER_Updated'
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'Baseline', f'{year}_GER_Updated') 
    path_to_baseline = os.path.join(project_folder, 'Mierendorff_full', f'{year}_GER_Updated')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
    except WindowsError:
        pass

# %%
# Model Standard 
# Model Year 
# Model 1st_Use 
shape_gpd = gpd.read_file(os.path.join(project_folder, 'Baseline', '2020_GER_Updated', "inputs", "building-geometry", "zone.shp"))
type_gpd = gpd.read_file(os.path.join(project_folder, 'Baseline', '2020_GER_Updated', "inputs", "building-properties", "typology.dbf"))

# %%
# Visualize building that could not be assigned an archetype
no_archetype = overlap[overlap["ARCHETYPE"].isnull()]["Name"].tolist()
shape_gpd[shape_gpd["Name"].isin(no_archetype)].plot()

# %%
# Analzye the building types that could not be assigned an archetype
shape_gpd[shape_gpd["Name"].isin(no_archetype)].category.value_counts()

# %%
shape_gpd[shape_gpd["Name"].isin(no_archetype) & shape_gpd["category"].isin(["yes"])].plot()

# %%
# After visual inspection, yes it it mostly buildings that are related to an type, e.g. the sheds. 
# Get rid of all building smaller than 100m2
shape_gpd["area"] = shape_gpd["geometry"].area
bigger_shape = shape_gpd[shape_gpd["area"] > 100]
bigger_shape[bigger_shape["category"].isin(["yes"])].plot()

# %%
shape_gpd[shape_gpd["area"] > 100 ].category.value_counts()

# %%
small_buildings = shape_gpd[shape_gpd['area'] < 100]['Name'].tolist()

# %%
# Calibration with Archetypes
# For checking different renovation status
# Random Assesment of year for Non Residential Buildings
renovation_arechteypes= ["" , "NR", "AR"] 
non_residential_variations = ["_A", "_B", "_C"]

# %%
# For AB type buildings after 1978 no data is available
# Model them as MF 

def find__enhanced_year_range(bldg_type, year):
    # function determines the year range that a given year falls into based on its categorization  
    if bldg_type in ["yes", "apartments", "residential", "house"]:
        #determine bldg age groups on years
        if 1860 <= year <= 1918:
            return "1860-1918"
        elif 1919 <= year <= 1948:
            return "1919-1948"
        elif 1949 <= year <= 1957:
            return "1949-1957"
        elif 1958 <= year <= 1968:
            return "1958-1968"
        elif 1969 <= year <= 1978:
            return "1969-1978"
        elif 1979 <= year <= 1983:
            return "1979-1983"
        elif 1984 <= year <= 1994:
            return "1984-1994"
        elif 1995 <= year <= 2001:
            return "1995-2001"
        elif 2002 <= year <= 2009:
            return "2002-2009"
        elif 2010 <= year <= 2015:
            return "2010-2015"
        elif 2016 <= year <= 2030:
            return "2016-2030"
        else:
            return None
    else:
        # Non Residential building groups
        if 1860 <= year <= 1978:
            return "1860-1978"
        elif 1979 <= year <= 2009:
            return "1979-2009"
        elif 2010 <= year <= 2030:
            return "2010-2030"
        else:
            return None
        
# ADD MFH Archetypes for Apparments constructed after 1978
ENHANCED_ARCHETYPES = {
     "apartments": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
        '1979-1983' : "MFH_G",
        "1984-1994" : "MFH_H",
        "1995-2001" : "MFH_I",
        "2002-2009" : "MFH_J",
        "2010-2015" : "MFH_K",
        "2016-2030" : "MFH_L",
    },
    "residential": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
        '1979-1983' : "MFH_G",
        "1984-1994" : "MFH_H",
        "1995-2001" : "MFH_I",
        "2002-2009" : "MFH_J",
        "2010-2015" : "MFH_K",
        "2016-2030" : "MFH_L",
    },
      "yes": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
        '1979-1983' : "MFH_G",
        "1984-1994" : "MFH_H",
        "1995-2001" : "MFH_I",
        "2002-2009" : "MFH_J",
        "2010-2015" : "MFH_K",
        "2016-2030" : "MFH_L",
    },
    "industrial": {
        "1860-1978": "NWG_G2_A",
        "1979-2009": "NWG_G2_B",
        "2010-2030": "NWG_G2_C",
    }, 

    "office": {
        "1860-1978": "NWG_1_A",
        "1979-2009": "NWG_1_B",
        "2010-2030": "NWG_1_C",
    },
      "commercial": {
        "1860-1978": "NWG_G1_A",
        "1979-2009": "NWG_G1_B",
        "2010-2030": "NWG_G1_C",
    }, 
    "retail" : {
        "1860-1978": "NWG_G1_A",
        "1979-2009": "NWG_G1_B",
        "2010-2030": "NWG_G1_C",
    }, 
    "warehouse": {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
        "service" : {
            "1860-1978": "NWG_10_A",
        "1979-2009": "NWG_10_B",
        "2010-2030": "NWG_10_C",
        },
        "school": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    },
    "public": {
        "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }, 
    "house": {
        "1860-1918": "AB_B",
        "1919-1948": "AB_C",
        "1949-1957": "AB_D",
        "1958-1968": "AB_E",
        "1969-1978": "AB_F",
    },"manufacture" : {
        "1860-1978": "NWG_8_A",
        "1979-2009": "NWG_8_B",
        "2010-2030": "NWG_8_C",
    }, 
    
        "kindergarten": {
        "1860-1978": "NWG_4_A",
        "1979-2009": "NWG_4_B",
        "2010-2030": "NWG_4_C",
    }, 
    "sports_hall": {
        "1860-1978": "NWG_6_A",
        "1979-2009": "NWG_6_B",
        "2010-2030": "NWG_6_C",
    }
    , 
    "church": {
        "1860-1978": "NWG_5_A",
        "1979-2009": "NWG_5_B",
        "2010-2030": "NWG_5_C",
    }}

# %%
def match_enhanced_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        print(year)
        return None 
    year_range = find__enhanced_year_range(bldg_type, average_year)
    if bldg_type in ENHANCED_ARCHETYPES and year_range in ENHANCED_ARCHETYPES[bldg_type]:
        return ENHANCED_ARCHETYPES[bldg_type][year_range]
    return None


overlap["ENHANCED_ARCHETYPE"] = overlap.apply(lambda row: match_enhanced_building_type(row['category'], row['ueberw_dek']), axis=1)

# %%
overlap[overlap["ueberw_dek"] == "gemischte Baualtersklasse"][['x_bis_1900', 'x1901_1910', 'x1911_1920', 'x1921_1930', 'x1931_1940', 'x1941_1950', 'x1951_1960', 'x1961_1970', 'x1971_1980', 'x1981_1990', 'x1991_2000', 'x2001_2010', 'x2011_2015']]

# %%
# Model them all as AB_B, as majortiy of buildings is somewhat in this category
overlap.loc[overlap['ueberw_dek'] == 'gemischte Baualtersklasse', 'ENHANCED_ARCHETYPE'] = 'AB_B'

# %%
def get_year(year_range):
    # Convert NaN and float to string or handle them separately
    if pd.isna(year_range):
        return None  # Handle NaN values explicitly
    if not isinstance(year_range, str):
        year_range = str(year_range)  # Convert non-string to string

    # Now the original logic, slightly adjusted for clarity
    if '-' in year_range:
        start_year, end_year = year_range.split('-')
        average_year = (int(start_year) + int(end_year)) // 2
        return average_year
    elif year_range == "gemischte Baualtersklasse":  # Fixed the condition checks
        return 1918
    elif year_range == "bis 1900":
        return 1900
    elif year_range == "NaN":  # This check might be redundant now
        return None

    try:
        return int(year_range)  # Handles cases where the year is not a range but a single year
    except ValueError:
        # Handles any unexpected string that cannot be converted directly to int
        return None

overlap["YEAR"] = overlap.apply(lambda row: get_year(row['ueberw_dek']), axis=1)

# %%
# Assign 1ST_USE type 
def match_1st_use_building_type( bldg_type, year):
    # This function matches building use to its archetype based on year
    try:
        average_year = average_year_from_range(year)
    except (TypeError, ValueError) as e:
        print(year)
        return None 
    year_range = find__enhanced_year_range(bldg_type, average_year)
    if bldg_type in ENHANCED_ARCHETYPES and year_range in ENHANCED_ARCHETYPES[bldg_type]:
        return ENHANCED_ARCHETYPES[bldg_type][year_range]
    return None

# %%
overlap["ARCHETYPE"].value_counts().index
# Assumptions
# For all residential building types, the MULTI_RES is assigned
# For office (NWG1), OFFICE is assigned
# For University (NWG2), UNIVERSITY is assigned
# For IWU Health and care buildings (NWG3), HEALTH is assigned
# For School (NWG4), SCHOOL is assigned
# # For culture, MUSEUM is assigned
# For all industrial buildings, INDUSTRIAL is assigned
# For IWU Technial buildings, TECHNICAL is assigned
USE_DICT = {
    'MFH_J': "MULTI_RES",
    'AB_B': "MULTI_RES",
    'AB_D': "MULTI_RES",
    'MFH_K': "MULTI_RES",
    'AB_C': "MULTI_RES",
    'NWG_5_A': "MUSEUM",
    'NWG_G2_C': "UNIVERSITY",
    'MFH_H': "MULTI_RES",
    'NWG_G1_B': "OFFICE",
    'NWG_G1_C': "OFFICE",
    'NWG_4_A': "SCHOOL",
    'NWG_G1_A': "OFFICE",
    'NWG_G2_A': "INDUSTRIAL",
    'NWG_1_B': "OFFICE",
    'NWG_8_B': "MULTI_RES",
    'NWG_1_A': "MULTI_RES",
    'NWG_10_B': "MULTI_RES",
    'NWG_6_A': "MULTI_RES",
    'NWG_1_C': "OFFICE",
    'NWG_10_A': "INDUSTRIAL",
    'NWG_10_C': "MULTI_RES"
}
overlap["1ST_USE"] = overlap["ENHANCED_ARCHETYPE"].map(USE_DICT)

# %%
buildings_assigned_standard = overlap[overlap["1ST_USE"].notnull()]["Name"].tolist()

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    config.project = os.path.join(project_folder, 'Baseline')
    config.scenario_name = f'{year}_GER_Updated'
    # create the destination path for copying the baseline scenario
    path_to_new_scenario = os.path.join(project_folder, 'Baseline', f'{year}_GER_Updated') 
    path_to_baseline = os.path.join(project_folder, 'Mierendorff_full', f'{year}_GER_Updated')
    try:
        shutil.copytree(path_to_baseline, path_to_new_scenario)
    except WindowsError:
        pass

# %%
# Now generate a model, where everythin is modeled at as least one building type 
import cea.config
config = cea.config.Configuration()
config.multiprocessing = True
years = ["2020", "2021", "2022"]

for year in years: 
    archetype_path = os.path.join(project_folder, 'Baseline', f'{year}_GER_Updated', "inputs", "building-properties", "typology.dbf")
    archetype_file = gpd.read_file(archetype_path)
    archetype_file["STANDARD"] = np.where(pd.isna(overlap["ARCHETYPE"]), overlap["ENHANCED_ARCHETYPE"], overlap["ARCHETYPE"])
    archetype_file["1ST_USE"] = overlap["1ST_USE"]
    archetype_file["YEAR"] = overlap["YEAR"]
    no_archetype = archetype_file[archetype_file["STANDARD"].isnull()]["Name"].tolist()
    #archetype_file.to_file(archetype_path)
    '''    zone_gdf = gpd.read_file(path_to_new_scenario + '/inputs/building-geometry/zone.shp')
    zone_gdf.drop(zone_gdf[~zone_gdf['Name'].isin(buildings_assigned_standard)].index, inplace=True)
    zone_gdf.to_file(path_to_new_scenario + '/inputs/building-geometry/zone.shp')


    #config.archetypes_mapper.buildings = list_assigned_standard
    config.schedule_maker.buildings = buildings_assigned_standard
    archetypes_mapper(locator=cea.inputlocator.InputLocator(config.scenario), 
                      update_architecture_dbf=False, update_air_conditioning_systems_dbf=False, 
                      update_indoor_comfort_dbf=False, update_internal_loads_dbf=False, 
                      update_supply_systems_dbf=False, update_schedule_operation_cea=True, 
                      buildings=buildings_assigned_standard)
    schedule_maker(config)
    #config.radiation.buildings = list_assigned_standard
    config.radiation.buildings = buildings_assigned_standard
    radiation_main(config)
    #config.demand.buildings = list_assigned_standard
    config.demand.overheating_warning = False
    demand_main(config) 
    '''

# %%
overlap

# %%
[x for x in list(archetype_file["Name"]) if x not in list(overlap["Name"])]

# %%
config.scenario
